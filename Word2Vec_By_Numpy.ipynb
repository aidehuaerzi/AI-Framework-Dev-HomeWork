# %%
import os
import mmap
import collections
import numpy as np
import random


# 数据预处理
# 读取数据
data_dir = "../dataset"
text = []
with open(os.path.join(data_dir, "text8"), "r") as f:
    # 创建内存映射
    mmapped_file = mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ)
    text = mmapped_file.read().decode('utf-8')
    mmapped_file.close()


# 字符太多，只取前50000
print("text长度为: " + str(len(text)))
text = text[:50000]
print(text)
print(collections.Counter(text).most_common(20 - 1))
count = [['UNK', -1]]
print(text.split())
words = text.split()
print(collections.Counter(words))
count.extend(collections.Counter(words))
print(count)
# Out:
# text长度为: 713069767
#  anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic institutions anarchists advocate social relations based upon voluntary association of autonomous individuals mutual aid and self governance while anarchism is most easily defined by what it is against anarchists also offer positive visions of what they believe to be a truly free society however ideas about how an anarchist society might work vary considerably especially with respect to economics there is also disagreement about how a free society might be brought about origins and predecessors kropotkin and others argue that before recorded history human society was organized on anarchist principles most anthropologists follow kropotkin and engels in believing that hunter gatherer bands were egalitarian and lacked division of labour accumulated wealth or decreed law and had equal access to resources william godwin anarchists including the the anarchy organisation and rothbard find anarchist attitudes in taoism from ancient china kropotkin found similar ideas in stoic zeno of citium according to kropotkin zeno repudiated the omnipotence of the state its intervention and regimentation and proclaimed the sovereignty of the moral law of the individual the anabaptists of one six th century europe are sometimes considered to be religious forerunners of modern anarchism bertrand russell in his history of western philosophy writes that the anabaptists repudiated all law since they held that the good man will be guided at every moment by the holy spirit from this premise they arrive at communism the diggers or true levellers were an early communistic movement during the time of the english civil war and are considered by some as forerunners of modern anarchism in the modern era the first to use the term to mean something other than chaos was louis armand baron de lahontan in his nouveaux voyages dans l am rique septentrionale one seven zero three where he described the indigenous american society which had no state laws prisons priests or private property as being in anarchy russell means a libertarian and leader in the american indian movement has repeatedly stated that he is an anarchist and so are all his ancestors in one seven nine three in the thick of the french revolution william godwin published an enquiry concerning political justice although godwin did not use the word anarchism many later anarchists have regarded this book as the first major anarchist text and godwin as the founder of philosophical anarchism but at this point no anarchist movement yet existed and the term anarchiste was known mainly as an insult hurled by the bourgeois girondins at more radical elements in the french revolution the first self labelled anarchist pierre joseph proudhon it is commonly held that it wasn t until pierre joseph proudhon published what is property in one eight four zero that the term anarchist was adopted as a self description it is for this reason that some claim proudhon as the founder of modern anarchist theory in what is property proudhon answers with the f ...
# [(' ', 7883), ('e', 4539), ('i', 3816), ('a', 3727), ('t', 3723), ('n', 3367), ('s', 3195), ('o', 3195), ('r', 2719), ('h', 1951), ('c', 1662), ('l', 1561), ('d', 1359), ('m', 1239), ('u', 1072), ('f', 881), ('p', 843), ('g', 647), ('y', 605)]
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'society', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'to', 'economics', 'there', 'is', 'also', 'disagreement', 'about', 'how', 'a', 'free', 'society', 'might', 'be', 'brought', 'about', 'origins', 'and', 'predecessors', 'kropotkin', 'and', 'others', 'argue', 'that', 'before', 'recorded', 'history', 'human', 'society', 'was', 'organized', 'on', 'anarchist', 'principles', 'most', 'anthropologists', 'follow', 'kropotkin', 'and', 'engels', 'in', 'believing', 'that', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'and', 'lacked', 'division', 'of', 'labour', 'accumulated', 'wealth', 'or', 'decreed', 'law', 'and', 'had', 'equal', 'access', 'to', 'resources', 'william', 'godwin', 'anarchists', 'including', 'the', 'the', 'anarchy', 'organisation', 'and', 'rothbard', 'find', 'anarchist', 'attitudes', 'in', 'taoism', 'from', 'ancient', 'china', 'kropotkin', 'found', 'similar', 'ideas', 'in', 'stoic', 'zeno', 'of', 'citium', 'according', 'to', 'kropotkin', 'zeno', 'repudiated', 'the', 'omnipotence', 'of', 'the', 'state', 'its', 'intervention', 'and', 'regimentation', 'and', 'proclaimed', 'the', 'sovereignty', 'of', 'the', 'moral', 'law', 'of', 'the', 'individual', 'the', 'anabaptists', 'of', 'one', 'six', 'th', 'century', 'europe', 'are', 'sometimes', 'considered', 'to', 'be', 'religious', 'forerunners', 'of', 'modern', 'anarchism', 'bertrand', 'russell', 'in', 'his', 'history', 'of', 'western', 'philosophy', 'writes', 'that', 'the', 'anabaptists', 'repudiated', 'all', 'law', 'since', 'they', 'held', 'that', 'the', 'good', 'man', 'will', 'be', 'guided', 'at', 'every', 'moment', 'by', 'the', 'holy', 'spirit', 'from', 'this', 'premise', 'they', 'arrive', 'at', 'communism', 'the', 'diggers', 'or', 'true', 'levellers', 'were', 'an', 'early', 'communistic', 'movement', 'during', 'the', 'time', 'of', 'the', 'english', 'civil', 'war', 'and', 'are', 'considered', 'by', 'some', 'as', 'forerunners', 'of', 'modern', 'anarchism', 'in', 'the', 'modern', 'era', 'the', 'first', 'to', 'use', 'the', 'term', 'to', 'mean', ...
# Counter({'the': 460, 'of': 305, 'and': 252, 'in': 201, 'to': 148, 'a': 142, 'one': 117, 'as': 108, 'anarchism': 102, 'is': 89, 'that': 81, 'anarchists': 76, 'anarchist': 69, 'nine': 62, 's': 59, 'zero': 55, 'by': 46, 'with': 45, 'for': 45, 'was': 42, 'it': 38, 'an': 38, 'eight': 38, 'or': 36, 'be': 34, 'are': 33, 'some': 33, 'anarcho': 33, 'on': 32, 'many': 30, 'such': 28, 'two': 28, 'from': 27, 'this': 27, 'see': 27, 'also': 26, 'most': 26, 'not': 26, 'movement': 26, 'have': 26, 'state': 25, 'which': 24, 'first': 22, 'social': 22, 'they': 22, 'its': 22, 'his': 22, 'autism': 22, 'society': 21, 'three': 21, 'other': 20, 'he': 20, 'six': 19, 'at': 19, 'property': 19, 'has': 18, 'ideas': 18, 'often': 18, 'post': 18, 'movements': 17, 'anti': 17, 'war': 17, 'seven': 17, 'groups': 17, 'term': 16, 'against': 16, 'authoritarian': 16, 'anarchy': 16, 'use': 16, 'proudhon': 16, 'their': 16, 'were': 15, 'form': 15, 'capitalism': 15, 'been': 14, 'there': 14, 'more': 14, 'four': 14, 'workers': 14, 'within': 14, 'cnt': 14, 'violence': 14, 'autistic': 14, 'early': 13, 'however': 13, 'all': 13, 'bakunin': 13, 'who': 13, 'used': 12, 'revolution': 12, 'what': 12, 'but': 12, 'general': 12, 'feminist': 12, 'means': 11, 'called': 11, 'spanish': 11, 'left': 11, 'class': 10, 'self': 10, 'political': 10, 'philosophy': 10, 'individuals': 10, 'about': 10, 'than': 10, 'would': 10, 'five': 10, 'both': 10, 'people': 10, 'syndicalism': 10, 'feminism': 10, 'including': 9, 'kropotkin': 9, 'others': 9, 'communism': 9, 'civil': 9, 'international': 9, 'include': 9, 'industrial': 9, 'world': 9, 'action': 9, 'anarcha': 9, 'should': 8, 'although': 8, 'economic': 8, 'work': 8, 'had': 8, 'individual': 8, 'century': 8, 'modern': 8, 'major': 8, 'labor': 8, 'right': 8, 'thought': 8, 'individualist': 8, 'revolutionary': 8, 'if': 8, 'communists': 8, 'nature': 8, 'christian': 8, 'spain': 8, 'government': 8, 'french': 7, 'institutions': 7, 'based': 7, 'free': 7, 'since': 7, 'will': 7, 'libertarian': 7, 'published': 7, 't': 7, 'can': 7, 'i': 7, 'tucker': 7, 'warren': 7, 'years': 7, 'system': 7, 'united': 7, 'communist': 7, 'may': 7, 'us': 7, 'goldman': 7, 'example': 7, 'must': 7, 'leo': 7, 'fascist': 7, 'different': 7, 'authority': 7, 'non': 7, 'these': 7, 'list': 7, 'english': 6, 'violent': 6, 'up': 6, 'advocate': 6, 'structures': 6, 'believe': 6, 'principles': 6, 'labour': 6, 'th': 6, 'europe': 6, 'considered': 6, 'religious': 6, 'de': 6, 'where': 6, 'described': 6, 'american': 6, 'no': 6, 'so': 6, 'theory': 6, 'opposed': 6, 'supported': 6, 'number': 6, 'own': 6, 'conflict': 6, 'liberty': 6, 'links': 6, 'force': 6, 'tolstoy': 6, 'associated': 6, 'like': 6, 'those': 6, 'group': 6, 'fascism': 6, 'working': 5, 'word': 5, 'without': 5, 'association': 5, 'mutual': 5, 'while': 5, 'how': 5, 'argue': 5, 'history': 5, 'law': 5, 'godwin': 5, 'rothbard': 5, 'sovereignty': 5, 'sometimes': 5, 'time': 5, 'point': 5, 'known': 5, 'famous': 5, 'complete': 5, 'trade': 5, 'france': 5, 'over': 5, 'stirner': 5, 'when': 5, 'power': 5, 'benjamin': 5, 'communities': 5, 'became': 5, 'theorists': 5, 'marx': 5, 'after': 5, 'emma': 5, 'syndicalist': 5, 'late': 5, 'black': 5, 'cgt': 5, 'members': 5, 'today': 5, 'bolsheviks': 5, 'led': 5, 'fascists': 5, 'popular': 5, 'even': 5, 'green': 5, 'books': 5, 'capitalist': 5, 'schools': 5, 'small': 5, 'cultural': 5, 'voting': 5, 'child': 5, 'conditions': 5, 'disorders': 5, 'asperger': 5, 'any': 4, 'organization': 4, 'label': 4, 'belief': 4, 'interpretations': 4, 'particularly': 4, 'does': 4, 'autonomous': 4, 'aid': 4, 'might': 4, 'before': 4, 'william': 4, 'similar': 4, 'western': 4, 'true': 4, 'during': 4, 'private': 4, 'being': 4, 'later': 4, 'book': 4, 'joseph': 4, 'until': 4, 'rights': 4, 'involved': 4, 'join': 4, 'set': 4, 'active': 4, 'egoism': 4, 'natural': 4, 'through': 4, 'new': 4, 'much': 4, 'wrote': 4, 'market': 4, 'her': 4, 'believed': 4, 'competition': 4, 'mikhail': 4, 'european': 4, 'due': 4, 'marxist': 4, 'person': 4, 'journal': 4, 'important':  ...
# [['UNK', -1], 'anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'english', 'revolution', 'and', 'sans', 'culottes', 'french', 'whilst', 'is', 'still', 'in', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'violent', 'means', 'destroy', 'organization', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'word', 'derived', 'from', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'political', 'philosophy', 'belief', 'rulers', 'are', 'unnecessary', 'should', 'be', 'abolished', 'although', 'there', 'differing', 'interpretations', 'what', 'this', 'refers', 'related', 'social', 'movements', 'advocate', 'elimination', 'authoritarian', 'institutions', 'particularly', 'state', 'anarchy', 'most', 'use', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'harmonious', 'anti', 'place', 'regarded', 'structures', 'coercive', 'economic', 'relations', 'based', 'upon', 'voluntary', 'association', 'autonomous', 'individuals', 'mutual', 'aid', 'governance', 'while', 'easily', 'offer', 'visions', 'they', 'believe', 'truly', 'free', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'economics', 'disagreement', 'brought', 'origins', 'predecessors', 'kropotkin', 'others', 'argue', 'before', 'recorded', 'history', 'human', 'was', 'organized', 'on', 'principles', 'anthropologists', 'follow', 'engels', 'believing', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'lacked', 'division', 'labour', 'accumulated', 'wealth', 'decreed', 'law', 'had', 'equal', 'access', 'resources', 'william', 'godwin', 'organisation', 'rothbard', 'find', 'attitudes', 'taoism', 'ancient', 'china', 'found', 'similar', 'stoic', 'zeno', 'citium', 'according', 'repudiated', 'omnipotence', 'its', 'intervention', 'regimentation', 'proclaimed', 'sovereignty', 'moral', 'individual', 'anabaptists', 'one', 'six', 'th', 'century', 'europe', 'sometimes', 'considered', 'religious', 'forerunners', 'modern', 'bertrand', 'russell', 'his', 'western', 'writes', 'all', 'since', 'held', 'good', 'man', 'will', 'guided', 'at', 'every', 'moment', 'holy', 'spirit', 'premise', 'arrive', 'communism', 'true', 'levellers', 'communistic', 'movement', 'during', 'time', 'civil', 'war', 'some', 'era', 'mean', 'something', 'other', 'than', 'louis', 'armand', 'baron', 'de', 'lahontan', 'nouveaux', 'voyages', 'dans', 'l', 'am', 'rique', 'septentrionale', 'seven', 'zero', 'three', 'where', 'he', 'described', 'indigenous', 'american', 'which', 'no', 'laws', 'prisons', 'priests', 'private', 'property', 'being', 'libertarian', 'leader', 'indian', 'repeatedly', 'stated', 'so', 'ancestors', 'nine', 'thick', 'published', 'enquiry', 'concerning', 'justice', 'did', 'many', 'later', 'have', 'book', 'major', 'text', 'founder', 'philosophical', 'point', 'yet', 'existed', 'anarchiste', 'known', 'mainly', 'insult', 'hurled', 'bourgeois', 'girondins', 'more', 'radical', 'elements', 'labelled', 'pierre', 'joseph', 'proudhon', 'commonly', 'wasn', 't', 'until', 'eight', 'four', 'adopted', 'description', 'for', 'reason', 'claim', 'theory', 'answers', 'famous', 'accusation', 'theft', 'opposed', 'institution', 'propri', 'owners', 'complete', 'rights', 'their', 'wish', 'such', 'exploiting', 'workers', 'profit', 'supported', 'called', 'possession', 'can', 'limited', 'capital', 'goods', 'accordance', 'equality', 's', 'vision', 'mutualism', 'mutuellisme', 'involved', 'exchange', 'economy', 'groups', 'could', 'trade', 'products', 'labor', 'using', 'notes', 'represented', 'amount', 'production', 'would', 'ensure', 'freely', 'join', 'together', 'co', 'operative', 'workshops', 'interest', 'bank', 'set', 'provide', 'everyone', 'influential', 'within', 'followers', 'active', 'france', 'complex', 'developed', 'number', 'works', 'over', 'lifeti ...

# %%
# 构造数据集
def build_dataset(words, vocab_size):
    count = [['UNK', -1]]
    # 选出最常见的vocab_size - 1个单词
    # count.extend(collections.Counter(words).most_common(vocab_size - 1))
    count.extend(collections.Counter(words).most_common())
    print("统计单词数量：", count)
    dictionary = {word: index for index, (word, _) in enumerate(count)}
    # 得到每个单词的索引
    data = [dictionary.get(word, 0) for word in words]
    count[0][1] = sum([1 for word in words if word not in dictionary])
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

words = text.split() # 得到text中的每个单词
vocab_size = 50000
data, count, dictionary, reverse_dictionary = build_dataset(words, vocab_size)

del words  # 释放内存
# Out:
# 统计单词数量： [['UNK', -1], ('the', 460), ('of', 305), ('and', 252), ('in', 201), ('to', 148), ('a', 142), ('one', 117), ('as', 108), ('anarchism', 102), ('is', 89), ('that', 81), ('anarchists', 76), ('anarchist', 69), ('nine', 62), ('s', 59), ('zero', 55), ('by', 46), ('with', 45), ('for', 45), ('was', 42), ('it', 38), ('an', 38), ('eight', 38), ('or', 36), ('be', 34), ('are', 33), ('some', 33), ('anarcho', 33), ('on', 32), ('many', 30), ('such', 28), ('two', 28), ('from', 27), ('this', 27), ('see', 27), ('also', 26), ('most', 26), ('not', 26), ('movement', 26), ('have', 26), ('state', 25), ('which', 24), ('first', 22), ('social', 22), ('they', 22), ('its', 22), ('his', 22), ('autism', 22), ('society', 21), ('three', 21), ('other', 20), ('he', 20), ('six', 19), ('at', 19), ('property', 19), ('has', 18), ('ideas', 18), ('often', 18), ('post', 18), ('movements', 17), ('anti', 17), ('war', 17), ('seven', 17), ('groups', 17), ('term', 16), ('against', 16), ('authoritarian', 16), ('anarchy', 16), ('use', 16), ('proudhon', 16), ('their', 16), ('were', 15), ('form', 15), ('capitalism', 15), ('been', 14), ('there', 14), ('more', 14), ('four', 14), ('workers', 14), ('within', 14), ('cnt', 14), ('violence', 14), ('autistic', 14), ('early', 13), ('however', 13), ('all', 13), ('bakunin', 13), ('who', 13), ('used', 12), ('revolution', 12), ('what', 12), ('but', 12), ('general', 12), ('feminist', 12), ('means', 11), ('called', 11), ('spanish', 11), ('left', 11), ('class', 10), ('self', 10), ('political', 10), ('philosophy', 10), ('individuals', 10), ('about', 10), ('than', 10), ('would', 10), ('five', 10), ('both', 10), ('people', 10), ('syndicalism', 10), ('feminism', 10), ('including', 9), ('kropotkin', 9), ('others', 9), ('communism', 9), ('civil', 9), ('international', 9), ('include', 9), ('industrial', 9), ('world', 9), ('action', 9), ('anarcha', 9), ('should', 8), ('although', 8), ('economic', 8), ('work', 8), ('had', 8), ('individual', 8), ('century', 8), ('modern', 8), ('major', 8), ('labor', 8), ('right', 8), ('thought', 8), ('individualist', 8), ('revolutionary', 8), ('if', 8), ('communists', 8), ('nature', 8), ('christian', 8), ('spain', 8), ('government', 8), ('french', 7), ('institutions', 7), ('based', 7), ('free', 7), ('since', 7), ('will', 7), ('libertarian', 7), ('published', 7), ('t', 7), ('can', 7), ('i', 7), ('tucker', 7), ('warren', 7), ('years', 7), ('system', 7), ('united', 7), ('communist', 7), ('may', 7), ('us', 7), ('goldman', 7), ('example', 7), ('must', 7), ('leo', 7), ('fascist', 7), ('different', 7), ('authority', 7), ('non', 7), ('these', 7), ('list', 7), ('english', 6), ('violent', 6), ('up', 6), ('advocate', 6), ('structures', 6), ('believe', 6), ('principles', 6), ('labour', 6), ('th', 6), ('europe', 6), ('considered', 6), ('religious', 6), ('de', 6), ('where', 6), ('described', 6), ('american', 6), ('no', 6), ('so', 6), ('theory', 6), ('opposed', 6), ('supported', 6), ('number', 6), ('own', 6), ('conflict', 6), ('liberty', 6), ('links', 6), ('force', 6), ('tolstoy', 6), ('associated', 6), ('like', 6), ('those', 6), ('group', 6), ('fascism', 6), ('working', 5), ('word', 5), ('without', 5), ('association', 5), ('mutual', 5), ('while', 5), ('how', 5), ('argue', 5), ('history', 5), ('law', 5), ('godwin', 5), ('rothbard', 5), ('sovereignty', 5), ('sometimes', 5), ('time', 5), ('point', 5), ('known', 5), ('famous', 5), ('complete', 5), ('trade', 5), ('france', 5), ('over', 5), ('stirner', 5), ('when', 5), ('power', 5), ('benjamin', 5), ('communities', 5), ('became', 5), ('theorists', 5), ('marx', 5), ('after', 5), ('emma', 5), ('syndicalist', 5), ('late', 5), ('black', 5), ('cgt', 5), ('members', 5), ('today', 5), ('bolsheviks', 5), ('led', 5), ('fascists', 5), ('popular', 5), ('even', 5), ('green', 5), ('books', 5), ('capitalist', 5), ('schools', 5), ('small', 5), ('cultural', 5), ('voting', 5), ('child', 5), ('conditions', 5), ('disorders', 5), ('asperger', 5), ('any', 4), ('organization', 4), ('label', 4), ('belie ...

# %%
# 生成训练数据 采用skip-gram模型
def generate_batch(data, batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

data_index = 0
batch, labels = generate_batch(data, batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 508 originated -> 9 anarchism
# 508 originated -> 8 as
# 8 as -> 6 a
# 8 as -> 508 originated
# 6 a -> 8 as
# 6 a -> 65 term
# 65 term -> 2 of
# 65 term -> 6 a

# %%
# 计算余弦相似度
def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)


# 最近邻查询
def get_nearest_neighbors(embedding_matrix, word_id, reverse_dictionary, top_k=10):
    word_vector = embedding_matrix[word_id]
    similarities = []
    for idx, vector in enumerate(embedding_matrix):
        if idx != word_id and idx in reverse_dictionary:
            similarity = cosine_similarity(word_vector, vector)
            similarities.append((idx, similarity))
    similarities.sort(key=lambda x: x[1], reverse=True)
    neighbors = [(reverse_dictionary[idx], similarity) for idx, similarity in similarities[:top_k]]
    return neighbors

def analogy_test(embedding_matrix, word1, word2, word3, dictionary, reverse_dictionary):
    vec1 = embedding_matrix[dictionary[word1]]
    vec2 = embedding_matrix[dictionary[word2]]
    vec3 = embedding_matrix[dictionary[word3]]
    target_vector = vec2 - vec1 + vec3

    similarities = []
    for idx, vector in enumerate(embedding_matrix):
        if idx not in [dictionary[word1], dictionary[word2], dictionary[word3]]:
            similarity = cosine_similarity(target_vector, vector)
            similarities.append((idx, similarity))
    similarities.sort(key=lambda x: x[1], reverse=True)
    return reverse_dictionary[similarities[0][0]]

# %%
from tqdm import tqdm

# 训练Word2Vec模型
class Word2Vec:
    def __init__(self, vocab_size, vector_dim, learning_rate):
        self.vocab_size = vocab_size
        self.vector_dim = vector_dim
        self.learning_rate = learning_rate
        self.W1 = np.random.rand(vocab_size, vector_dim)
        self.W2 = np.random.rand(vector_dim, vocab_size)

    def train(self, data, epochs, batch_size, num_skips, skip_window, reverse_dictionary, test_words):
        global data_index
        for epoch in tqdm(range(epochs)):
            data_index = 0
            batch_count = len(data) // batch_size
            for step in range(batch_count):
                batch_inputs, batch_labels = generate_batch(data, batch_size, num_skips, skip_window)
                for context_word, target_word in zip(batch_inputs, batch_labels):
                    y_true = np.zeros(self.vocab_size)
                    y_true[target_word] = 1
                    h = self.W1[context_word]
                    u = np.dot(self.W2.T, h)
                    y_pred = self.softmax(u)
                    e = y_pred - y_true
                    self.W1[context_word] -= self.learning_rate * np.dot(self.W2, e)
                    self.W2 -= self.learning_rate * np.outer(h, e)
            if (epoch + 1) % 5 == 0:
                print(f'Epoch {epoch + 1} completed')
                self.evaluate(reverse_dictionary, test_words)

    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum(axis=0)

    def get_word_vector(self, word_id):
        return self.W1[word_id]

    def evaluate(self, reverse_dictionary, test_words):
        print("Evaluating model...")
        for word_id in test_words:
            if word_id not in reverse_dictionary:
                continue  # 跳过不存在的单词ID
            neighbors = get_nearest_neighbors(self.W1, word_id, reverse_dictionary)
            print(f"Neighbors of {reverse_dictionary[word_id]}: Similarity")
            for neighbor, similarity in neighbors:
                print(f"  {neighbor}: {similarity:.4f}")

def generate_test_word_ids(dictionary, num_words=500):
    # 从词汇表的键中随机选择指定数量的单词
    word_ids = list(dictionary.values())
    random.shuffle(word_ids)
    return word_ids[:num_words]


# Example usage
vector_dim = 100
learning_rate = 0.01
epochs = 20
batch_size = 128
num_skips = 2
skip_window = 1

# 生成500个测试单词ID
test_word_ids = generate_test_word_ids(dictionary, num_words=500)

w2v = Word2Vec(vocab_size, vector_dim, learning_rate)
w2v.train(data, epochs, batch_size, num_skips, skip_window, reverse_dictionary, test_word_ids)
# Out:
#  20%|██        | 4/20 [06:11<24:46, 92.90s/it]
# Epoch 5 completed
# Evaluating model...
# Neighbors of capital: Similarity
#   oppressive: 0.8416
#   legitimacy: 0.8410
#   maintain: 0.8320
#   advocated: 0.8319
#   voting: 0.8314
#   using: 0.8302
#   archives: 0.8300
#   applying: 0.8277
#   relevant: 0.8250
#   arguing: 0.8237
# Neighbors of hop: Similarity
#   exponent: 0.8545
#   combination: 0.8543
#   regarding: 0.8527
#   models: 0.8491
#   failed: 0.8477
#   figureheads: 0.8468
#   unity: 0.8464
#   modern: 0.8454
#   celebrated: 0.8444
#   characterised: 0.8436
# Neighbors of colonialism: Similarity
#   followed: 0.8451
#   vary: 0.8416
#   unionist: 0.8363
#   operation: 0.8353
#   detailed: 0.8324
#   originally: 0.8301
#   feminism: 0.8280
#   proceeded: 0.8263
#   alternate: 0.8240
#   societies: 0.8238
# Neighbors of major: Similarity
#   seeks: 0.8280
#   infantile: 0.8230
#   authors: 0.8216
#   chomsky: 0.8205
#   positive: 0.8204
#   cases: 0.8204
#   developing: 0.8202
#   list: 0.8201
#   accept: 0.8200
#   conception: 0.8199
# Neighbors of defined: Similarity
#   he: 0.8593
#   rise: 0.8399
#   abacus: 0.8377
#   work: 0.8353
#   union: 0.8347
#   thought: 0.8322
#   e: 0.8313
#   confederaci: 0.8306
#   earned: 0.8298
#   reference: 0.8294
# Neighbors of regimentation: Similarity
#   rothbard: 0.8511
#   quickest: 0.8357
#   resist: 0.8333
#   democratic: 0.8330
#   federation: 0.8309
#   globalization: 0.8291
#   present: 0.8287
#   egalitarian: 0.8280
#   indeed: 0.8279
#   individualists: 0.8276
# Neighbors of main: Similarity
#   pseudo: 0.8151
#   utility: 0.8151
#   these: 0.8141
#   below: 0.8132
#   marxism: 0.8130
#   radicals: 0.8129
#   hans: 0.8098
#   figure: 0.8098
#   oppression: 0.8097
#   leading: 0.8087
# Neighbors of well: Similarity
#   vary: 0.8534
#   celebrated: 0.8454
#   comunismo: 0.8397
#   association: 0.8390
#   famous: 0.8371
#   meanings: 0.8351
#   start: 0.8348
#   neurodevelopmental: 0.8341
#   goods: 0.8332
#   wave: 0.8327
# Neighbors of purposes: Similarity
#   hop: 0.8337
#   organise: 0.8296
#   earned: 0.8253
#   losing: 0.8244
#   relevant: 0.8244
#   characteristic: 0.8237
#   failed: 0.8235
#   federation: 0.8211
#   critical: 0.8205
#   certainty: 0.8186
# Neighbors of give: Similarity
#   following: 0.8505
#   source: 0.8479
#   zeno: 0.8471
#   researchers: 0.8426
#   wolfi: 0.8399
#   sought: 0.8393
#   meanings: 0.8388
#   article: 0.8367
#   compete: 0.8357
#   privately: 0.8342
# Neighbors of churches: Similarity
#   freetown: 0.8332
#   areas: 0.8331
#   fascists: 0.8329
#   bombs: 0.8323
#   handle: 0.8318
#   chief: 0.8307
#   profits: 0.8292
#   formed: 0.8286
#   destroying: 0.8270
#   spooner: 0.8268
# Neighbors of participated: Similarity
#   voluntaryism: 0.8471
#   hip: 0.8465
#   favor: 0.8458
#   fascism: 0.8446
#   aid: 0.8419
#   civilization: 0.8418
#   activists: 0.8392
#   he: 0.8383
#   terms: 0.8379
#   minor: 0.8364
# Neighbors of plain: Similarity
#   hop: 0.8424
#   birth: 0.8306
#   opponents: 0.8280
#   modern: 0.8274
#   celebrated: 0.8240
#   workingmen: 0.8235
#   pacifism: 0.8224
#   criticised: 0.8220
#   left: 0.8214
#   dissident: 0.8198
# Neighbors of attachment: Similarity
#   union: 0.8300
#   external: 0.8222
#   lead: 0.8194
#   nechaev: 0.8165
#   detailed: 0.8158
#   sought: 0.8129
#   hakim: 0.8123
#   founded: 0.8119
#   dielo: 0.8118
#   anarchy: 0.8105
# Neighbors of imaginable: Similarity
#   m: 0.8391
#   formed: 0.8209
#   experimental: 0.8208
#   maintained: 0.8203
#   need: 0.8200
#   interfering: 0.8190
#   famous: 0.8187
#   bordering: 0.8185
#   him: 0.8179
#   clinicians: 0.8173
# Neighbors of meeting: Similarity
#   absolute: 0.8431
#   work: 0.8389
#   characterised: 0.8387
#   important: 0.8362
#   g: 0.8360
#   look: 0.8354
#   referenced: 0.8336
#   rossell: 0.8324
#   socialist: 0.8316
#   warren: 0.8301
# Neighbors of two: Similarity
#   my: 0.8461
#   offer: 0.8452
#   operation: 0.8379
#   follow: 0.8351
#   he: 0.8348
#   against: 0.8329
#   owen: 0.8329
#   polarised: 0.8315
#   considered: 0.8295
#   le: 0.8284
# Neighbors of ungodly: Similarity
#   experiences: 0.8376
#   infoshop: 0.8310
#   french: 0.8305
#   hierarchies: 0.8300
#   seeks: 0.8293
#   governance: 0.8255
#   terms: 0.8243
#   feminism: 0.8233
#   focus: 0.8202
#   revolution: 0.8195
# Neighbors of makes: Similarity
#   helped: 0.8541
#   oppression: 0.8360
#   religious: 0.8323
#   middle: 0.8317
#   disorders: 0.8298
#   catalonia: 0.8285
#   have: 0.8282
#   radicals: 0.8263
#   elections: 0.8259
#   associated: 0.8256
# Neighbors of terms: Similarity
#   separate: 0.8449
#   place: 0.8418
#   him: 0.8409
#   followed: 0.8400
#   participated: 0.8379
#   principle: 0.8374
#   widely: 0.8367
#   glorification: 0.8359
#   tend: 0.8354
#   evolution: 0.8341
# Neighbors of postanarchism: Similarity
#   supplant: 0.8275
#   workingmen: 0.8250
#   argued: 0.8211
#   still: 0.8193
#   randolph: 0.8188
#   individuals: 0.8183
#   unlike: 0.8170
#   seeks: 0.8153
#   corrupted: 0.8150
#   bleed: 0.8133
# Neighbors of contrary: Similarity
#   patterns: 0.8384
#   suppression: 0.8302
#   pseudo: 0.8298
#   alongside: 0.8296
#   while: 0.8280
#   relevant: 0.8280
#   develop: 0.8279
#   characteristic: 0.8275
#   organisations: 0.8268
#   repudiated: 0.8261
# Neighbors of mcquinn: Similarity
#   does: 0.8336
#   psychiatrist: 0.8315
#   delay: 0.8307
#   owen: 0.8303
#   goods: 0.8272
#   whatever: 0.8244
#   he: 0.8236
#   him: 0.8219
#   earned: 0.8211
#   kind: 0.8204
# Neighbors of organising: Similarity
#   gun: 0.8427
#   globalization: 0.8319
#   seeks: 0.8241
#   fair: 0.8233
#   anarchy: 0.8232
#   revolutionaries: 0.8228
#   great: 0.8224
#   ballots: 0.8217
#   rome: 0.8208
#   deal: 0.8206
# Neighbors of victory: Similarity
#   are: 0.8335
#   joined: 0.8304
#   affected: 0.8246
#   used: 0.8239
#   also: 0.8238
#   history: 0.8229
#   influential: 0.8223
#   socialism: 0.8223
#   event: 0.8216
#   translated: 0.8211
# Neighbors of canada: Similarity
#   create: 0.8420
#   characterised: 0.8411
#   activists: 0.8348
#   arrive: 0.8327
#   article: 0.8326
#   justice: 0.8308
#   copenhagen: 0.8303
#   million: 0.8283
#   give: 0.8265
#   nechaev: 0.8248
# Neighbors of anarchiste: Similarity
#   coercion: 0.8364
#   council: 0.8362
#   overthrown: 0.8334
#   taken: 0.8255
#   were: 0.8204
#   famous: 0.8187
#   levellers: 0.8180
#   periodical: 0.8166
#   parties: 0.8162
#   communes: 0.8162
# Neighbors of dedicated: Similarity
#   anarchism: 0.8476
#   developments: 0.8423
#   movement: 0.8378
#   seemed: 0.8375
#   denounced: 0.8338
#   principles: 0.8320
#   prominent: 0.8306
#   governance: 0.8296
#   stimulations: 0.8292
#   crimethinc: 0.8288
# Neighbors of nonviolence: Similarity
#   applying: 0.8424
#   follow: 0.8229
#   symbolic: 0.8170
#   robert: 0.8166
#   pervasive: 0.8160
#   received: 0.8138
#   notion: 0.8134
#   event: 0.8092
#   grouped: 0.8087
#   following: 0.8086
# Neighbors of temporary: Similarity
#   communes: 0.8552
#   began: 0.8506
#   expression: 0.8490
#   avant: 0.8452
#   hans: 0.8407
#   justify: 0.8405
#   levellers: 0.8341
#   discussion: 0.8319
#   dominance: 0.8258
#   earned: 0.8255
# Neighbors of oppressive: Similarity
#   predictions: 0.8610
#   equality: 0.8596
#   leading: 0.8527
#   stanley: 0.8503
#   racial: 0.8466
#   founder: 0.8445
#   than: 0.8432
#   vary: 0.8429
#   hand: 0.8421
#   found: 0.8420
# Neighbors of cars: Similarity
#   association: 0.8293
#   louis: 0.8260
#   says: 0.8178
#   attempted: 0.8166
#   developed: 0.8126
#   october: 0.8103
#   tradition: 0.8090
#   komboa: 0.8070
#   pearl: 0.8059
#   distributed: 0.8051
# Neighbors of destroy: Similarity
#   believing: 0.8268
#   aiming: 0.8184
#   repressive: 0.8161
#   unrealistically: 0.8101
#   respective: 0.8075
#   greek: 0.8072
#   principles: 0.8067
#   of: 0.8056
#   moral: 0.8026
#   isaac: 0.8025
# Neighbors of bey: Similarity
#   million: 0.8146
#   majority: 0.8120
#   favor: 0.8117
#   zeno: 0.8112
#   repression: 0.8090
#   against: 0.8082
#   creation: 0.8061
#   spooner: 0.8053
#   complex: 0.7990
#   article: 0.7987
# Neighbors of beneficial: Similarity
#   participate: 0.8365
#   don: 0.8336
#   start: 0.8301
#   exponent: 0.8282
#   lead: 0.8271
#   dilettantes: 0.8215
#   characterised: 0.8207
#   my: 0.8191
#   oppression: 0.8186
#   minor: 0.8183
# Neighbors of hart: Similarity
#   also: 0.8446
#   liberation: 0.8378
#   oppression: 0.8326
#   imaginative: 0.8313
#   accept: 0.8238
#   color: 0.8203
#   restricted: 0.8195
#   synthesis: 0.8182
#   consequently: 0.8178
#   wealth: 0.8164
# Neighbors of coercive: Similarity
#   and: 0.8348
#   discussion: 0.8339
#   saw: 0.8327
#   then: 0.8326
#   structure: 0.8319
#   todd: 0.8280
#   might: 0.8265
#   manifestation: 0.8233
#   most: 0.8229
#   lead: 0.8214
# Neighbors of opportunities: Similarity
#   hand: 0.8313
#   occupation: 0.8291
#   concluded: 0.8289
#   bourses: 0.8275
#   prisons: 0.8273
#   impossible: 0.8269
#   contexts: 0.8251
#   tactical: 0.8247
#   pseudo: 0.8207
#   deal: 0.8199
# Neighbors of individualistically: Similarity
#   religious: 0.8371
#   crimethinc: 0.8311
#   lifetime: 0.8245
#   g: 0.8232
#   structures: 0.8227
#   oppression: 0.8216
#   wing: 0.8204
#   bertrand: 0.8173
#   autos: 0.8165
#   needs: 0.8145
# Neighbors of revolutionary: Similarity
#   alternative: 0.8462
#   economic: 0.8427
#   overthrown: 0.8386
#   work: 0.8379
#   following: 0.8378
#   quickest: 0.8377
#   meanings: 0.8376
#   exploited: 0.8345
#   broader: 0.8303
#   operation: 0.8299
# Neighbors of competiting: Similarity
#   oppression: 0.8237
#   technological: 0.8221
#   evil: 0.8180
#   international: 0.8152
#   support: 0.8138
#   victorious: 0.8125
#   helped: 0.8113
#   internationals: 0.8110
#   mikhail: 0.8108
#   occasionally: 0.8102
# Neighbors of austrian: Similarity
#   globalization: 0.8489
#   whites: 0.8339
#   elected: 0.8206
#   organise: 0.8200
#   membership: 0.8173
#   errico: 0.8169
#   stanley: 0.8164
#   agricultural: 0.8151
#   losing: 0.8145
#   followed: 0.8139
# Neighbors of establishment: Similarity
#   following: 0.8451
#   quickest: 0.8336
#   climaxed: 0.8317
#   precursor: 0.8308
#   majority: 0.8299
#   areas: 0.8291
#   physical: 0.8279
#   those: 0.8242
#   might: 0.8240
#   rale: 0.8236
# Neighbors of radically: Similarity
#   levellers: 0.8255
#   publications: 0.8248
#   condition: 0.8223
#   espouses: 0.8218
#   he: 0.8207
#   experiment: 0.8205
#   inspired: 0.8198
#   means: 0.8198
#   seeks: 0.8185
#   religion: 0.8182
# Neighbors of historical: Similarity
#   mutualism: 0.8314
#   teachings: 0.8306
#   broad: 0.8258
#   thereof: 0.8209
#   offshoots: 0.8167
#   occupation: 0.8151
#   failed: 0.8132
#   societies: 0.8121
#   civilization: 0.8111
#   needs: 0.8108
# Neighbors of syncretic: Similarity
#   alternative: 0.8570
#   five: 0.8487
#   organisations: 0.8424
#   description: 0.8401
#   response: 0.8388
#   failed: 0.8385
#   red: 0.8381
#   describe: 0.8374
#   man: 0.8374
#   roles: 0.8363
# Neighbors of critique: Similarity
#   play: 0.8257
#   pearl: 0.8251
#   this: 0.8249
#   formed: 0.8233
#   aiming: 0.8225
#   twenty: 0.8212
#   history: 0.8207
#   bank: 0.8190
#   supplant: 0.8186
#   handle: 0.8185
# Neighbors of classes: Similarity
#   alongside: 0.8539
#   significant: 0.8528
#   late: 0.8485
#   citium: 0.8465
#   justice: 0.8461
#   absence: 0.8457
#   labor: 0.8455
#   community: 0.8430
#   many: 0.8430
#   hierarchy: 0.8410
# Neighbors of seismic: Similarity
#   internet: 0.8385
#   economics: 0.8309
#   over: 0.8302
#   resist: 0.8299
#   researchers: 0.8297
#   federation: 0.8271
#   join: 0.8258
#   mean: 0.8256
#   referenced: 0.8249
#   streets: 0.8248
# Neighbors of by: Similarity
#   relevant: 0.8615
#   activists: 0.8436
#   garde: 0.8417
#   component: 0.8384
#   scale: 0.8377
#   equality: 0.8364
#   justify: 0.8340
#   october: 0.8331
#   degrees: 0.8330
#   occasionally: 0.8325
# Neighbors of attempted: Similarity
#   inspired: 0.8490
#   where: 0.8412
#   offshoots: 0.8373
#   famous: 0.8360
#   needed: 0.8351
#   us: 0.8342
#   communists: 0.8331
#   repressive: 0.8328
#   dangerous: 0.8315
#   komboa: 0.8301
# Neighbors of paper: Similarity
#   aiming: 0.8423
#   annihilation: 0.8362
#   ballots: 0.8305
#   swiss: 0.8238
#   professionals: 0.8222
#   joy: 0.8173
#   female: 0.8168
#   bank: 0.8163
#   areas: 0.8158
#   earned: 0.8147
# Neighbors of could: Similarity
#   dilettantes: 0.8403
#   komboa: 0.8318
#   respect: 0.8204
#   researchers: 0.8202
#   federation: 0.8181
#   prevalent: 0.8168
#   find: 0.8163
#   heads: 0.8160
#   technological: 0.8159
#   he: 0.8135
# Neighbors of details: Similarity
#   journal: 0.8508
#   dynamost: 0.8393
#   symbolic: 0.8383
#   criticised: 0.8375
#   am: 0.8374
#   genes: 0.8363
#   since: 0.8362
#   now: 0.8360
#   french: 0.8346
#   psychology: 0.8335
# Neighbors of symbolic: Similarity
#   began: 0.8598
#   respect: 0.8571
#   organise: 0.8535
#   activists: 0.8520
#   relevant: 0.8483
#   oppression: 0.8482
#   however: 0.8408
#   warren: 0.8396
#   e: 0.8396
#   nihilist: 0.8393
# Neighbors of org: Similarity
#   harmony: 0.8304
#   capitalists: 0.8244
#   ancestors: 0.8207
#   grouped: 0.8161
#   detailed: 0.8106
#   seeks: 0.8075
#   success: 0.8068
#   membership: 0.8049
#   catalonia: 0.8040
#   insurrection: 0.8027
# Neighbors of all: Similarity
#   later: 0.8389
#   referred: 0.8381
#   zapatista: 0.8311
#   of: 0.8297
#   refuted: 0.8292
#   army: 0.8258
#   regarding: 0.8253
#   bourses: 0.8205
#   berkman: 0.8203
#   portrayed: 0.8200
# Neighbors of she: Similarity
#   vegan: 0.8547
#   tree: 0.8322
#   UNK: 0.8258
#   developments: 0.8232
#   branches: 0.8228
#   affected: 0.8198
#   three: 0.8196
#   quickest: 0.8188
#   thick: 0.8175
#   vary: 0.8169
# Neighbors of laws: Similarity
#   bob: 0.8507
#   oppression: 0.8477
#   wiki: 0.8396
#   economics: 0.8331
#   e: 0.8318
#   reformist: 0.8278
#   chaos: 0.8256
#   riots: 0.8253
#   same: 0.8251
#   oppressive: 0.8234
# Neighbors of several: Similarity
#   evil: 0.8343
#   to: 0.8324
#   rise: 0.8287
#   joined: 0.8285
#   can: 0.8274
#   by: 0.8265
#   outright: 0.8244
#   formed: 0.8243
#   situationism: 0.8238
#   situationists: 0.8235
# Neighbors of abundance: Similarity
#   zapatista: 0.8455
#   recognise: 0.8370
#   bourgeoisie: 0.8368
#   foreign: 0.8358
#   economics: 0.8341
#   celebrated: 0.8297
#   internal: 0.8296
#   experimental: 0.8290
#   another: 0.8287
#   group: 0.8286
# Neighbors of ex: Similarity
#   earned: 0.8295
#   ireland: 0.8287
#   without: 0.8281
#   domestically: 0.8243
#   results: 0.8231
#   truly: 0.8225
#   limited: 0.8137
#   component: 0.8110
#   moral: 0.8085
#   population: 0.8084
# Neighbors of appleton: Similarity
#   bombs: 0.8614
#   membership: 0.8454
#   crimethinc: 0.8453
#   occasionally: 0.8431
#   talk: 0.8394
#   organise: 0.8341
#   age: 0.8329
#   says: 0.8321
#   inspired: 0.8321
#   writing: 0.8314
# Neighbors of away: Similarity
#   capitalist: 0.8317
#   neighborhood: 0.8301
#   explains: 0.8294
#   graeber: 0.8258
#   annihilation: 0.8230
#   religious: 0.8191
#   mysogyny: 0.8112
#   satisfaction: 0.8095
#   along: 0.8092
#   egoism: 0.8085
# Neighbors of l: Similarity
#   freedom: 0.8132
#   struggle: 0.8106
#   internationals: 0.8086
#   his: 0.8057
#   informal: 0.8051
#   infoshops: 0.8047
#   respective: 0.8041
#   quickest: 0.8033
#   oppression: 0.8030
#   embraces: 0.8028
# Neighbors of imprisoned: Similarity
#   shares: 0.8253
#   howard: 0.8226
#   worked: 0.8206
#   entertainer: 0.8173
#   t: 0.8173
#   radically: 0.8166
#   inspired: 0.8159
#   try: 0.8155
#   serious: 0.8149
#   five: 0.8149
# Neighbors of gnu: Similarity
#   crimethinc: 0.8504
#   anarchists: 0.8489
#   impossible: 0.8430
#   move: 0.8423
#   classes: 0.8365
#   king: 0.8353
#   decades: 0.8351
#   taking: 0.8351
#   since: 0.8347
#   french: 0.8343
# Neighbors of whatever: Similarity
#   dominance: 0.8458
#   interfering: 0.8405
#   worldview: 0.8362
#   domestically: 0.8357
#   wealth: 0.8339
#   legitimacy: 0.8333
#   history: 0.8325
#   referred: 0.8310
#   while: 0.8295
#   soviet: 0.8270
# Neighbors of regarded: Similarity
#   majority: 0.8316
#   ever: 0.8263
#   cease: 0.8209
#   century: 0.8203
#   anarcha: 0.8197
#   need: 0.8197
#   tree: 0.8181
#   weakened: 0.8175
#   flag: 0.8173
#   limited: 0.8170
# Neighbors of possession: Similarity
#   origin: 0.8326
#   relevant: 0.8257
#   since: 0.8244
#   clinicians: 0.8232
#   source: 0.8225
#   bleed: 0.8221
#   seeks: 0.8188
#   stabalised: 0.8183
#   mainly: 0.8182
#   pearl: 0.8182
# Neighbors of whoever: Similarity
#   anarchist: 0.8475
#   moral: 0.8381
#   against: 0.8355
#   heavily: 0.8350
#   swiss: 0.8319
#   crimethinc: 0.8300
#   meanings: 0.8267
#   led: 0.8263
#   agitating: 0.8242
#   how: 0.8209
# Neighbors of existed: Similarity
#   history: 0.8453
#   hans: 0.8436
#   foreign: 0.8375
#   army: 0.8324
#   hierarchies: 0.8306
#   clinicians: 0.8285
#   ricourt: 0.8280
#   blogs: 0.8276
#   researchers: 0.8273
#   jesus: 0.8272
# Neighbors of leo: Similarity
#   thereof: 0.8449
#   worldview: 0.8424
#   structure: 0.8360
#   destroying: 0.8358
#   work: 0.8342
#   inclined: 0.8337
#   rique: 0.8304
#   common: 0.8299
#   flag: 0.8299
#   explaining: 0.8291
# Neighbors of competition: Similarity
#   areas: 0.8641
#   sees: 0.8592
#   property: 0.8590
#   importance: 0.8580
#   todd: 0.8577
#   abolished: 0.8555
#   exhibits: 0.8503
#   flag: 0.8464
#   taking: 0.8462
#   f: 0.8454
# Neighbors of mutualism: Similarity
#   black: 0.8422
#   see: 0.8414
#   incorporated: 0.8364
#   rose: 0.8359
#   societies: 0.8329
#   historical: 0.8314
#   nihilism: 0.8305
#   broad: 0.8296
#   bank: 0.8292
#   tends: 0.8279
# Neighbors of alliances: Similarity
#   focuses: 0.8562
#   work: 0.8515
#   absolute: 0.8388
#   individualists: 0.8371
#   sitting: 0.8362
#   quickest: 0.8362
#   historian: 0.8352
#   grouped: 0.8344
#   perhaps: 0.8334
#   suppressed: 0.8330
# Neighbors of leading: Similarity
#   oppressive: 0.8527
#   five: 0.8511
#   berkman: 0.8414
#   power: 0.8378
#   bordering: 0.8377
#   population: 0.8365
#   age: 0.8360
#   prior: 0.8355
#   benjamin: 0.8329
#   syncretic: 0.8323
# Neighbors of business: Similarity
#   founded: 0.8399
#   alternative: 0.8363
#   religious: 0.8326
#   policy: 0.8223
#   accept: 0.8194
#   oppression: 0.8187
#   felt: 0.8185
#   use: 0.8137
#   revolutionary: 0.8134
#   joy: 0.8130
# Neighbors of figureheads: Similarity
#   societies: 0.8588
#   hop: 0.8468
#   typically: 0.8381
#   founded: 0.8355
#   linking: 0.8333
#   able: 0.8324
#   proprietor: 0.8305
#   criticisms: 0.8288
#   adopted: 0.8279
#   celebrities: 0.8277
# Neighbors of absence: Similarity
#   classes: 0.8457
#   attitudes: 0.8381
#   germinal: 0.8331
#   dilettantes: 0.8324
#   higher: 0.8296
#   justice: 0.8293
#   indeed: 0.8258
#   since: 0.8252
#   behaviors: 0.8239
#   anarchism: 0.8237
# Neighbors of began: Similarity
#   symbolic: 0.8598
#   sovereignty: 0.8583
#   power: 0.8521
#   bonanno: 0.8520
#   temporary: 0.8506
#   price: 0.8479
#   army: 0.8479
#   considered: 0.8453
#   stabalised: 0.8441
#   chaos: 0.8440
# Neighbors of preserving: Similarity
#   calls: 0.8237
#   opinion: 0.8221
#   issues: 0.8177
#   generalizations: 0.8167
#   heads: 0.8162
#   use: 0.8142
#   autonomous: 0.8126
#   limited: 0.8118
#   uprising: 0.8111
#   behavior: 0.8111
# Neighbors of anabaptist: Similarity
#   opinion: 0.8335
#   anarchist: 0.8316
#   would: 0.8249
#   frederick: 0.8228
#   need: 0.8200
#   introduced: 0.8189
#   equality: 0.8189
#   opportunities: 0.8187
#   proudhon: 0.8182
#   bombs: 0.8173
# Neighbors of mechanisms: Similarity
#   motion: 0.8500
#   noam: 0.8464
#   degrees: 0.8457
#   forms: 0.8456
#   stoic: 0.8405
#   event: 0.8392
#   moral: 0.8387
#   economics: 0.8385
#   signficiant: 0.8381
#   grouped: 0.8366
# Neighbors of interfering: Similarity
#   active: 0.8625
#   interpretations: 0.8569
#   detailed: 0.8441
#   develops: 0.8433
#   xu: 0.8428
#   overthrown: 0.8425
#   principles: 0.8423
#   editor: 0.8414
#   most: 0.8412
#   proprietor: 0.8412
# Neighbors of societies: Similarity
#   driven: 0.8682
#   berkman: 0.8591
#   figureheads: 0.8588
#   anarchist: 0.8550
#   problem: 0.8473
#   deal: 0.8471
#   del: 0.8467
#   compatibility: 0.8452
#   structuralism: 0.8437
#   look: 0.8431
# Neighbors of brief: Similarity
#   anarchists: 0.8210
#   dynamics: 0.8208
#   associations: 0.8184
#   federation: 0.8149
#   aggression: 0.8143
#   arguing: 0.8105
#   believed: 0.8096
#   offshoots: 0.8085
#   individualist: 0.8079
#   easily: 0.8079
# Neighbors of towards: Similarity
#   membership: 0.8331
#   activists: 0.8319
#   referenced: 0.8316
#   organization: 0.8312
#   discussion: 0.8312
#   bleed: 0.8307
#   patterns: 0.8300
#   failed: 0.8246
#   school: 0.8239
#   inspired: 0.8237
# Neighbors of criminality: Similarity
#   diagnostic: 0.8374
#   formed: 0.8284
#   regimentation: 0.8274
#   federation: 0.8253
#   raico: 0.8232
#   benjamin: 0.8231
#   parliamentarianism: 0.8231
#   referred: 0.8224
#   says: 0.8217
#   bourses: 0.8203
# Neighbors of technological: Similarity
#   respect: 0.8310
#   lead: 0.8302
#   competiting: 0.8221
#   label: 0.8189
#   dilettantes: 0.8187
#   democratic: 0.8184
#   contexts: 0.8179
#   oppression: 0.8163
#   could: 0.8159
#   smith: 0.8143
# Neighbors of manual: Similarity
#   professionals: 0.8243
#   communist: 0.8216
#   anarchy: 0.8179
#   nechaev: 0.8170
#   voting: 0.8166
#   riot: 0.8148
#   developments: 0.8144
#   earned: 0.8144
#   construct: 0.8133
#   enemies: 0.8127
# Neighbors of luigi: Similarity
#   assert: 0.8489
#   ill: 0.8325
#   respected: 0.8321
#   authoritarian: 0.8285
#   indymedia: 0.8200
#   vii: 0.8178
#   publicly: 0.8169
#   expression: 0.8150
#   competition: 0.8145
#   earth: 0.8143
# Neighbors of august: Similarity
#   term: 0.8441
#   february: 0.8418
#   over: 0.8383
#   science: 0.8346
#   perhaps: 0.8329
#   began: 0.8317
#   experiment: 0.8286
#   mikhail: 0.8258
#   monopoly: 0.8255
#   modern: 0.8243
# Neighbors of made: Similarity
#   anti: 0.8275
#   economic: 0.8256
#   arms: 0.8248
#   destruction: 0.8221
#   condition: 0.8204
#   attitudes: 0.8189
#   oppression: 0.8157
#   occasionally: 0.8151
#   vulnerabilities: 0.8143
#   institution: 0.8141
# Neighbors of aiming: Similarity
#   utopianism: 0.8558
#   paper: 0.8423
#   he: 0.8421
#   grouped: 0.8419
#   utility: 0.8395
#   anarchy: 0.8361
#   classes: 0.8347
#   failed: 0.8332
#   authority: 0.8326
#   need: 0.8325
# Neighbors of widespread: Similarity
#   influence: 0.8417
#   insurrections: 0.8348
#   quickest: 0.8280
#   bombs: 0.8268
#   minimized: 0.8267
#   term: 0.8265
#   inspired: 0.8263
#   seeks: 0.8262
#   monopoly: 0.8260
#   truly: 0.8254
# Neighbors of party: Similarity
#   petite: 0.8379
#   unionist: 0.8357
#   classes: 0.8340
#   similarities: 0.8335
#   oppression: 0.8328
#   individualist: 0.8316
#   age: 0.8301
#   civilization: 0.8300
#   saw: 0.8296
#   occurs: 0.8296
# Neighbors of etc: Similarity
#   spirituality: 0.8488
#   among: 0.8476
#   and: 0.8475
#   inherent: 0.8429
#   organise: 0.8410
#   repression: 0.8397
#   chaos: 0.8359
#   dr: 0.8341
#   supplant: 0.8336
#   institution: 0.8335
# Neighbors of chief: Similarity
#   genes: 0.8373
#   began: 0.8355
#   experiences: 0.8327
#   participated: 0.8325
#   birth: 0.8308
#   churches: 0.8307
#   pervasive: 0.8305
#   signficiant: 0.8300
#   does: 0.8298
#   much: 0.8291
# Neighbors of their: Similarity
#   also: 0.8556
#   newman: 0.8520
#   revolutionaries: 0.8485
#   respect: 0.8452
#   proceeded: 0.8437
#   spoilt: 0.8433
#   seminal: 0.8429
#   punk: 0.8419
#   since: 0.8419
#   bob: 0.8404
# Neighbors of views: Similarity
#   make: 0.8260
#   riot: 0.8229
#   distance: 0.8160
#   crimethinc: 0.8143
#   flag: 0.8129
#   neal: 0.8110
#   mass: 0.8099
#   majority: 0.8091
#   accept: 0.8089
#   rebellion: 0.8058
# Neighbors of subjugation: Similarity
#   if: 0.8279
#   see: 0.8229
#   uprising: 0.8220
#   caused: 0.8199
#   private: 0.8184
#   among: 0.8150
#   religiousity: 0.8144
#   holder: 0.8129
#   pre: 0.8121
#   don: 0.8113
# Neighbors of founder: Similarity
#   characterised: 0.8454
#   oppressive: 0.8445
#   stanley: 0.8422
#   komboa: 0.8356
#   following: 0.8340
#   predictions: 0.8339
#   seeks: 0.8320
#   robert: 0.8319
#   ricourt: 0.8309
#   create: 0.8306
# Neighbors of blogs: Similarity
#   hans: 0.8583
#   luddites: 0.8386
#   unionism: 0.8320
#   primitive: 0.8301
#   reformist: 0.8299
#   following: 0.8296
#   read: 0.8295
#   socialist: 0.8287
#   seeking: 0.8287
#   existed: 0.8276
# Neighbors of primitivism: Similarity
#   musical: 0.8403
#   final: 0.8383
#   degree: 0.8361
#   external: 0.8347
#   foreign: 0.8306
#   oppressive: 0.8304
#   adjectives: 0.8280
#   christiania: 0.8263
#   magazines: 0.8262
#   dr: 0.8261
# Neighbors of signficiant: Similarity
#   five: 0.8548
#   hundreds: 0.8542
#   gatherer: 0.8450
#   quite: 0.8446
#   earned: 0.8418
#   seize: 0.8415
#   dangerous: 0.8409
#   decreed: 0.8392
#   mechanisms: 0.8381
#   taoism: 0.8367
# Neighbors of coup: Similarity
#   religion: 0.8229
#   disorders: 0.8193
#   saw: 0.8171
#   insurrections: 0.8157
#   levellers: 0.8135
#   protesters: 0.8117
#   expansion: 0.8102
#   believes: 0.8102
#   present: 0.8081
#   announced: 0.8074
# Neighbors of non: Similarity
#   inspired: 0.8254
#   tend: 0.8238
#   internationals: 0.8222
#   starhawk: 0.8180
#   possible: 0.8126
#   unnecessary: 0.8126
#   present: 0.8103
#   takes: 0.8081
#   liberation: 0.8081
#   ungodly: 0.8072
# Neighbors of christiania: Similarity
#   zapatista: 0.8440
#   owned: 0.8396
#   popularized: 0.8349
#   reformist: 0.8337
#   to: 0.8295
#   referred: 0.8279
#   army: 0.8279
#   anomie: 0.8267
#   occasionally: 0.8264
#   primitivism: 0.8263
# Neighbors of calls: Similarity
#   civilization: 0.8428
#   mikhail: 0.8404
#   sans: 0.8331
#   meanings: 0.8311
#   since: 0.8296
#   green: 0.8279
#   participated: 0.8263
#   right: 0.8248
#   tend: 0.8246
#   occur: 0.8243
# Neighbors of opposes: Similarity
#   abstention: 0.8307
#   million: 0.8307
#   grouped: 0.8295
#   times: 0.8275
#   hospital: 0.8268
#   fascism: 0.8267
#   contrary: 0.8258
#   levellers: 0.8246
#   late: 0.8233
#   catalonia: 0.8230
# Neighbors of stalinists: Similarity
#   damage: 0.8549
#   council: 0.8411
#   region: 0.8410
#   traditions: 0.8371
#   opposed: 0.8356
#   present: 0.8333
#   institute: 0.8332
#   clearly: 0.8324
#   says: 0.8318
#   received: 0.8301
# Neighbors of nine: Similarity
#   critical: 0.8190
#   zero: 0.8168
#   internationals: 0.8126
#   insurrections: 0.8119
#   earned: 0.8106
#   factors: 0.8060
#   peter: 0.8022
#   fighting: 0.8003
#   owen: 0.8003
#   germinal: 0.7999
# Neighbors of onset: Similarity
#   extensively: 0.8491
#   obediance: 0.8470
#   famous: 0.8332
#   institution: 0.8328
#   theft: 0.8281
#   believes: 0.8269
#   meanings: 0.8269
#   repudiated: 0.8265
#   elections: 0.8260
#   advocated: 0.8244
# Neighbors of was: Similarity
#   receiving: 0.8477
#   list: 0.8458
#   culture: 0.8451
#   killing: 0.8446
#   inclined: 0.8435
#   organise: 0.8434
#   statism: 0.8434
#   george: 0.8398
#   societies: 0.8384
#   impossible: 0.8371
# Neighbors of so: Similarity
#   abnormal: 0.8225
#   encyclopedia: 0.8197
#   directly: 0.8196
#   article: 0.8171
#   out: 0.8165
#   stimulations: 0.8165
#   earned: 0.8163
#   anarcha: 0.8154
#   rousseau: 0.8151
#   wave: 0.8149
# Neighbors of libertario: Similarity
#   against: 0.8415
#   intervene: 0.8394
#   imposing: 0.8372
#   found: 0.8347
#   vulnerabilities: 0.8321
#   god: 0.8317
#   oppression: 0.8307
#   physicians: 0.8305
#   proto: 0.8297
#   tend: 0.8290
# Neighbors of malatesta: Similarity
#   rural: 0.8168
#   dave: 0.8155
#   symbolic: 0.8115
#   economical: 0.8080
#   social: 0.8056
#   oppression: 0.8045
#   since: 0.8029
#   bank: 0.8027
#   began: 0.8025
#   notion: 0.8000
# Neighbors of commonly: Similarity
#   seeks: 0.8372
#   membership: 0.8305
#   democratic: 0.8165
#   characteristic: 0.8151
#   b: 0.8120
#   might: 0.8114
#   unconnected: 0.8090
#   races: 0.8070
#   history: 0.8056
#   roles: 0.8050
# Neighbors of rothbard: Similarity
#   resist: 0.8556
#   regimentation: 0.8511
#   formed: 0.8454
#   predictions: 0.8409
#   bombs: 0.8399
#   translated: 0.8383
#   oppression: 0.8381
#   quickest: 0.8353
#   earned: 0.8326
#   joy: 0.8321
# Neighbors of anthropologists: Similarity
#   moment: 0.8371
#   famous: 0.8322
#   failed: 0.8274
#   organise: 0.8252
#   arms: 0.8229
#   individualist: 0.8222
#   anarchy: 0.8202
#   arguing: 0.8182
#   anarchists: 0.8180
#   utopian: 0.8170
# Neighbors of confines: Similarity
#   neocolonialism: 0.8317
#   work: 0.8287
#   totalitarians: 0.8242
#   owned: 0.8236
#   oppression: 0.8171
#   prior: 0.8157
#   confederaci: 0.8149
#   perhaps: 0.8133
#   such: 0.8132
#   noted: 0.8100
# Neighbors of appeared: Similarity
#   handle: 0.8438
#   absolute: 0.8375
#   second: 0.8362
#   collectivized: 0.8312
#   tend: 0.8290
#   informal: 0.8283
#   marxist: 0.8272
#   inspired: 0.8234
#   king: 0.8218
#   followed: 0.8215
# Neighbors of formation: Similarity
#   classes: 0.8401
#   style: 0.8379
#   used: 0.8376
#   since: 0.8368
#   nevertheless: 0.8363
#   creation: 0.8357
#   separate: 0.8346
#   congress: 0.8324
#   council: 0.8323
#   taking: 0.8314
# Neighbors of headed: Similarity
#   disappears: 0.8288
#   seeking: 0.8277
#   and: 0.8245
#   minarchists: 0.8220
#   sitting: 0.8212
#   join: 0.8200
#   flag: 0.8193
#   g: 0.8166
#   formulation: 0.8163
#   making: 0.8160
# Neighbors of decide: Similarity
#   squatter: 0.8542
#   cost: 0.8409
#   unionist: 0.8373
#   tacitly: 0.8360
#   modern: 0.8331
#   seeking: 0.8314
#   damage: 0.8305
#   i: 0.8298
#   what: 0.8297
#   libertarian: 0.8294
# Neighbors of fall: Similarity
#   considered: 0.8285
#   justice: 0.8274
#   exploiting: 0.8231
#   bitter: 0.8199
#   leading: 0.8185
#   hop: 0.8166
#   that: 0.8148
#   t: 0.8131
#   destroying: 0.8129
#   mikhail: 0.8129
# Neighbors of expose: Similarity
#   science: 0.8569
#   perhaps: 0.8402
#   interfering: 0.8353
#   condition: 0.8321
#   famous: 0.8306
#   leftists: 0.8304
#   classes: 0.8261
#   is: 0.8256
#   proclivities: 0.8223
#   saw: 0.8205
# Neighbors of franco: Similarity
#   characterized: 0.8274
#   alternative: 0.8217
#   description: 0.8162
#   list: 0.8145
#   leadership: 0.8138
#   mutuellisme: 0.8117
#   alfredo: 0.8108
#   pdd: 0.8103
#   xu: 0.8096
#   exile: 0.8093
# Neighbors of often: Similarity
#   alexander: 0.8174
#   seeks: 0.8155
#   operation: 0.8113
#   komboa: 0.8077
#   include: 0.8071
#   peter: 0.8065
#   vision: 0.8062
#   desirable: 0.8028
#   successful: 0.8021
#   grouped: 0.8018
# Neighbors of capitalist: Similarity
#   developments: 0.8496
#   relevant: 0.8433
#   mean: 0.8396
#   issued: 0.8392
#   philosophy: 0.8349
#   resist: 0.8329
#   away: 0.8317
#   religious: 0.8313
#   oppression: 0.8302
#   private: 0.8289
# Neighbors of cited: Similarity
#   population: 0.8160
#   widespread: 0.8148
#   komboa: 0.8147
#   legitimacy: 0.8096
#   those: 0.8083
#   utility: 0.8079
#   bank: 0.8052
#   organization: 0.8041
#   someone: 0.8029
#   refuted: 0.8028
# Neighbors of federation: Similarity
#   covered: 0.8435
#   color: 0.8424
#   insanity: 0.8392
#   and: 0.8369
#   revolutionist: 0.8329
#   dogmatic: 0.8329
#   worldview: 0.8325
#   offshoots: 0.8321
#   however: 0.8319
#   consider: 0.8315
# Neighbors of outposts: Similarity
#   contexts: 0.8558
#   alston: 0.8434
#   seeking: 0.8407
#   referred: 0.8394
#   premise: 0.8358
#   however: 0.8353
#   kingdom: 0.8344
#   artist: 0.8317
#   justice: 0.8302
#   wrote: 0.8300
# Neighbors of hague: Similarity
#   certainly: 0.8302
#   taxation: 0.8220
#   offer: 0.8215
#   inspired: 0.8198
#   housing: 0.8191
#   communistic: 0.8174
#   same: 0.8166
#   positive: 0.8160
#   differing: 0.8159
#   addresses: 0.8157
# Neighbors of girondins: Similarity
#   take: 0.8302
#   uprisings: 0.8199
#   moral: 0.8174
#   famous: 0.8142
#   hop: 0.8131
#   detailed: 0.8118
#   zeno: 0.8091
#   principles: 0.8088
#   alliances: 0.8087
#   robert: 0.8062
# Neighbors of difference: Similarity
#   offshoots: 0.8271
#   meanings: 0.8261
#   dr: 0.8244
#   february: 0.8231
#   areas: 0.8230
#   vegetarian: 0.8223
#   regarding: 0.8190
#   broader: 0.8190
#   joined: 0.8179
#   component: 0.8177
# Neighbors of let: Similarity
#   principles: 0.8270
#   follow: 0.8239
#   my: 0.8222
#   rudolf: 0.8177
#   collectively: 0.8165
#   individualists: 0.8136
#   isaac: 0.8118
#   chinese: 0.8099
#   raico: 0.8091
#   might: 0.8086
# Neighbors of roots: Similarity
#   oppression: 0.8301
#   sexist: 0.8274
#   confused: 0.8271
#   komboa: 0.8225
#   high: 0.8218
#   varying: 0.8217
#   refuted: 0.8192
#   make: 0.8155
#   seeks: 0.8154
#   proprietor: 0.8153
# Neighbors of celebrities: Similarity
#   societies: 0.8364
#   figureheads: 0.8277
#   fundamental: 0.8275
#   nonetheless: 0.8246
#   decades: 0.8195
#   region: 0.8174
#   respect: 0.8153
#   north: 0.8153
#   propose: 0.8131
#   squatter: 0.8126
# Neighbors of publications: Similarity
#   followed: 0.8626
#   social: 0.8467
#   formed: 0.8453
#   french: 0.8428
#   losing: 0.8424
#   consequences: 0.8406
#   bank: 0.8382
#   history: 0.8363
#   destruction: 0.8341
#   five: 0.8314
# Neighbors of linking: Similarity
#   legitimacy: 0.8346
#   figureheads: 0.8333
#   contexts: 0.8290
#   housing: 0.8213
#   distinct: 0.8209
#   female: 0.8193
#   expense: 0.8189
#   dilettantes: 0.8176
#   socialism: 0.8172
#   failed: 0.8169
# Neighbors of therefore: Similarity
#   lingering: 0.8385
#   also: 0.8177
#   ungodly: 0.8161
#   insurrection: 0.8145
#   founder: 0.8142
#   differing: 0.8126
#   your: 0.8107
#   something: 0.8097
#   principles: 0.8083
#   individuals: 0.8032
# Neighbors of libertaire: Similarity
#   late: 0.8467
#   relevant: 0.8389
#   its: 0.8353
#   detailed: 0.8326
#   zinn: 0.8316
#   characteristic: 0.8311
#   alternative: 0.8301
#   bourses: 0.8263
#   army: 0.8258
#   cypherpunk: 0.8251
# Neighbors of direct: Similarity
#   population: 0.8166
#   easily: 0.8160
#   principles: 0.8152
#   union: 0.8140
#   earned: 0.8115
#   bitter: 0.8114
#   acts: 0.8113
#   figureheads: 0.8098
#   series: 0.8098
#   crimethinc: 0.8093
# Neighbors of folk: Similarity
#   methodology: 0.8296
#   website: 0.8234
#   collectivized: 0.8210
#   seeks: 0.8205
#   signficiant: 0.8171
#   syndicalist: 0.8162
#   conquest: 0.8159
#   destruction: 0.8158
#   feminism: 0.8152
#   ancestors: 0.8140
# Neighbors of must: Similarity
#   egoist: 0.8479
#   situationism: 0.8435
#   condition: 0.8430
#   ralph: 0.8385
#   detailed: 0.8382
#   revolution: 0.8374
#   arguing: 0.8357
#   was: 0.8338
#   hold: 0.8332
#   lot: 0.8307
# Neighbors of milieu: Similarity
#   equality: 0.8512
#   areas: 0.8384
#   on: 0.8370
#   operation: 0.8364
#   monopoly: 0.8363
#   respective: 0.8355
#   problem: 0.8348
#   evil: 0.8340
#   since: 0.8339
#   earned: 0.8320
# Neighbors of free: Similarity
#   kinds: 0.8287
#   defeat: 0.8205
#   hans: 0.8184
#   precursor: 0.8176
#   try: 0.8173
#   seeking: 0.8160
#   wish: 0.8150
#   neopagan: 0.8146
#   worker: 0.8139
#   skills: 0.8136
# Neighbors of justify: Similarity
#   work: 0.8545
#   internet: 0.8544
#   offshoots: 0.8532
#   communes: 0.8518
#   hans: 0.8509
#   leaving: 0.8459
#   history: 0.8447
#   frederick: 0.8423
#   voting: 0.8406
#   temporary: 0.8405
# Neighbors of researchers: Similarity
#   creation: 0.8678
#   also: 0.8536
#   hans: 0.8474
#   history: 0.8471
#   baltimore: 0.8453
#   child: 0.8435
#   give: 0.8426
#   hierarchy: 0.8414
#   feminism: 0.8390
#   strands: 0.8387
# Neighbors of external: Similarity
#   oppression: 0.8618
#   explains: 0.8455
#   try: 0.8441
#   relevant: 0.8404
#   globalization: 0.8358
#   primitivism: 0.8347
#   around: 0.8335
#   organisations: 0.8329
#   hakim: 0.8327
#   collectivized: 0.8312
# Neighbors of parties: Similarity
#   expansion: 0.8653
#   population: 0.8334
#   explained: 0.8304
#   attitudes: 0.8282
#   dielo: 0.8276
#   b: 0.8274
#   need: 0.8266
#   ayn: 0.8265
#   members: 0.8256
#   vote: 0.8209
# Neighbors of working: Similarity
#   usually: 0.8273
#   advocated: 0.8209
#   criticisms: 0.8186
#   lacan: 0.8177
#   stanley: 0.8163
#   negotiations: 0.8149
#   individualist: 0.8141
#   mikhail: 0.8138
#   talk: 0.8116
#   holy: 0.8109
# Neighbors of makhnovschina: Similarity
#   answers: 0.8362
#   activism: 0.8277
#   spanish: 0.8276
#   comunismo: 0.8264
#   delays: 0.8252
#   strike: 0.8238
#   have: 0.8226
#   practice: 0.8225
#   eastern: 0.8214
#   utopianism: 0.8192
# Neighbors of short: Similarity
#   relevant: 0.8396
#   crimethinc: 0.8321
#   collectives: 0.8303
#   oppression: 0.8265
#   use: 0.8261
#   proclaimed: 0.8240
#   disorder: 0.8221
#   addresses: 0.8213
#   accepted: 0.8201
#   wendy: 0.8194
# Neighbors of election: Similarity
#   komboa: 0.8372
#   harmony: 0.8360
#   spooner: 0.8345
#   rise: 0.8314
#   areas: 0.8310
#   related: 0.8292
#   how: 0.8282
#   preservation: 0.8247
#   decades: 0.8240
#   warren: 0.8231
# Neighbors of nonetheless: Similarity
#   european: 0.8332
#   term: 0.8308
#   products: 0.8282
#   societies: 0.8267
#   north: 0.8259
#   fundamental: 0.8257
#   figureheads: 0.8253
#   celebrities: 0.8246
#   great: 0.8238
#   accordance: 0.8235
# Neighbors of mainly: Similarity
#   possession: 0.8182
#   incorporated: 0.8180
#   signficiant: 0.8133
#   author: 0.8124
#   context: 0.8099
#   community: 0.8096
#   roles: 0.8090
#   regarding: 0.8080
#   advance: 0.8079
#   repudiated: 0.8077
# Neighbors of glorification: Similarity
#   place: 0.8539
#   statistical: 0.8485
#   spirituality: 0.8415
#   terms: 0.8359
#   egalitarian: 0.8353
#   stanley: 0.8349
#   damage: 0.8344
#   affected: 0.8338
#   defunct: 0.8333
#   unfeasible: 0.8326
# Neighbors of chomsky: Similarity
#   oppression: 0.8591
#   justice: 0.8527
#   army: 0.8503
#   division: 0.8430
#   great: 0.8396
#   formulation: 0.8385
#   infantile: 0.8361
#   operative: 0.8354
#   inspired: 0.8349
#   corresponding: 0.8348
# Neighbors of internal: Similarity
#   roles: 0.8336
#   following: 0.8318
#   abundance: 0.8296
#   others: 0.8200
#   decreed: 0.8196
#   rise: 0.8160
#   societies: 0.8160
#   monopoly: 0.8130
#   experimental: 0.8128
#   such: 0.8127
# Neighbors of assassinations: Similarity
#   since: 0.8430
#   individualist: 0.8369
#   conquest: 0.8337
#   regarding: 0.8293
#   hop: 0.8293
#   failed: 0.8278
#   amidst: 0.8259
#   advocates: 0.8259
#   stimulations: 0.8256
#   common: 0.8250
# Neighbors of hospital: Similarity
#   science: 0.8602
#   doctrines: 0.8515
#   chaos: 0.8363
#   internationals: 0.8355
#   johann: 0.8352
#   komboa: 0.8352
#   cercle: 0.8351
#   catalonia: 0.8335
#   workingmen: 0.8329
#   supplant: 0.8322
# Neighbors of label: Similarity
#   k: 0.8553
#   evil: 0.8391
#   individualists: 0.8390
#   seminal: 0.8369
#   physiologically: 0.8341
#   equality: 0.8330
#   ricardo: 0.8321
#   regarding: 0.8316
#   criticisms: 0.8303
#   differing: 0.8296
# Neighbors of mutualists: Similarity
#   compatibility: 0.8490
#   failed: 0.8400
#   neurodevelopmental: 0.8361
#   proprietor: 0.8316
#   component: 0.8287
#   individualist: 0.8274
#   experimental: 0.8265
#   someone: 0.8256
#   alternatives: 0.8255
#   tending: 0.8240
# Neighbors of unlike: Similarity
#   interpretations: 0.8422
#   narveson: 0.8343
#   failure: 0.8332
#   fascism: 0.8306
#   rulers: 0.8299
#   xu: 0.8298
#   science: 0.8292
#   anti: 0.8276
#   interfering: 0.8266
#   johns: 0.8262
# Neighbors of embodying: Similarity
#   crimethinc: 0.8289
#   signficiant: 0.8262
#   activists: 0.8225
#   action: 0.8214
#   without: 0.8204
#   errico: 0.8197
#   north: 0.8196
#   etiology: 0.8167
#   roles: 0.8167
#   characteristic: 0.8158
# Neighbors of predictions: Similarity
#   oppressive: 0.8610
#   crimethinc: 0.8602
#   victorious: 0.8486
#   felt: 0.8464
#   october: 0.8461
#   he: 0.8457
#   sharing: 0.8451
#   further: 0.8435
#   etiology: 0.8424
#   diagnostic: 0.8422
# Neighbors of theoretical: Similarity
#   tolstoy: 0.8274
#   formed: 0.8237
#   applying: 0.8229
#   sometimes: 0.8204
#   resist: 0.8170
#   typical: 0.8161
#   housing: 0.8146
#   philosophy: 0.8114
#   pervasive: 0.8109
#   attitudes: 0.8107
# Neighbors of historian: Similarity
#   alliances: 0.8352
#   criticisms: 0.8276
#   infoshops: 0.8196
#   elected: 0.8179
#   icd: 0.8179
#   compatibility: 0.8177
#   guided: 0.8173
#   leading: 0.8169
#   critical: 0.8164
#   then: 0.8159
# Neighbors of present: Similarity
#   reality: 0.8478
#   arguing: 0.8472
#   ultimately: 0.8465
#   crimethinc: 0.8459
#   operation: 0.8456
#   anti: 0.8442
#   bordering: 0.8415
#   prisons: 0.8409
#   see: 0.8403
#   itself: 0.8393
# Neighbors of stalinist: Similarity
#   feminism: 0.8396
#   occupation: 0.8392
#   stanley: 0.8357
#   alston: 0.8302
#   operative: 0.8298
#   viewed: 0.8226
#   interpretations: 0.8213
#   population: 0.8206
#   alliances: 0.8202
#   rousseau: 0.8193
# Neighbors of section: Similarity
#   generally: 0.8316
#   proprietor: 0.8277
#   against: 0.8275
#   doctrines: 0.8258
#   law: 0.8257
#   societies: 0.8256
#   originally: 0.8240
#   disobedience: 0.8231
#   changed: 0.8226
#   wrote: 0.8212
# Neighbors of forerunners: Similarity
#   comunismo: 0.8315
#   modern: 0.8314
#   soviet: 0.8237
#   because: 0.8234
#   kropotkin: 0.8194
#   work: 0.8185
#   green: 0.8184
#   dsm: 0.8149
#   hierarchies: 0.8141
#   history: 0.8138
# Neighbors of platform: Similarity
#   another: 0.8390
#   well: 0.8293
#   are: 0.8276
#   rome: 0.8273
#   hop: 0.8204
#   act: 0.8173
#   cost: 0.8155
#   utmost: 0.8133
#   idea: 0.8114
#   community: 0.8113
# Neighbors of mexico: Similarity
#   organise: 0.8337
#   dominance: 0.8318
#   fact: 0.8289
#   itself: 0.8277
#   oppression: 0.8263
#   widely: 0.8254
#   formed: 0.8253
#   rale: 0.8250
#   programming: 0.8245
#   repudiated: 0.8228
# Neighbors of form: Similarity
#   negotiations: 0.8397
#   principle: 0.8300
#   carrying: 0.8243
#   community: 0.8213
#   unrealistically: 0.8212
#   ralph: 0.8201
#   referred: 0.8194
#   significant: 0.8180
#   participated: 0.8178
#   article: 0.8178
# Neighbors of ashanti: Similarity
#   hans: 0.8424
#   delays: 0.8381
#   governance: 0.8255
#   develop: 0.8226
#   garde: 0.8225
#   joy: 0.8172
#   characterised: 0.8163
#   harmony: 0.8156
#   leadership: 0.8151
#   proto: 0.8151
# Neighbors of want: Similarity
#   against: 0.8359
#   sought: 0.8243
#   since: 0.8207
#   strands: 0.8204
#   joe: 0.8183
#   vulnerabilities: 0.8166
#   herbert: 0.8154
#   chomsky: 0.8149
#   offshoots: 0.8140
#   taoism: 0.8137
# Neighbors of re: Similarity
#   infantile: 0.8369
#   komboa: 0.8233
#   seismic: 0.8219
#   spanish: 0.8194
#   zerzan: 0.8181
#   racist: 0.8174
#   priests: 0.8173
#   e: 0.8166
#   believe: 0.8154
#   illustrated: 0.8154
# Neighbors of preferred: Similarity
#   respect: 0.8400
#   term: 0.8344
#   when: 0.8342
#   punk: 0.8274
#   also: 0.8236
#   b: 0.8225
#   council: 0.8220
#   decades: 0.8213
#   thereof: 0.8164
#   primitive: 0.8153
# Neighbors of rale: Similarity
#   yet: 0.8360
#   became: 0.8313
#   than: 0.8252
#   mexico: 0.8250
#   oppressive: 0.8241
#   bad: 0.8237
#   establishment: 0.8236
#   wish: 0.8232
#   focus: 0.8227
#   kind: 0.8212
# Neighbors of pouget: Similarity
#   began: 0.8391
#   oppression: 0.8373
#   perhaps: 0.8321
#   detailed: 0.8250
#   saw: 0.8228
#   capitalist: 0.8212
#   adults: 0.8191
#   anarchist: 0.8190
#   crimethinc: 0.8186
#   critical: 0.8184
# Neighbors of too: Similarity
#   globalization: 0.8414
#   anarchism: 0.8203
#   earned: 0.8184
#   economy: 0.8141
#   exhibits: 0.8140
#   prominent: 0.8096
#   utility: 0.8090
#   him: 0.8080
#   critical: 0.8067
#   also: 0.8056
# Neighbors of worked: Similarity
#   currents: 0.8479
#   appeal: 0.8410
#   operative: 0.8388
#   taking: 0.8374
#   much: 0.8356
#   g: 0.8352
#   oppression: 0.8346
#   anarchy: 0.8335
#   anarchism: 0.8312
#   does: 0.8308
# Neighbors of appropriate: Similarity
#   willful: 0.8454
#   five: 0.8263
#   infantile: 0.8244
#   collectivized: 0.8197
#   canada: 0.8173
#   dangerous: 0.8162
#   dominance: 0.8135
#   repression: 0.8129
#   refuted: 0.8123
#   relations: 0.8121
# Neighbors of pursuit: Similarity
#   and: 0.8429
#   unconnected: 0.8417
#   flag: 0.8344
#   late: 0.8342
#   occurs: 0.8325
#   if: 0.8323
#   results: 0.8297
#   mcelroy: 0.8291
#   place: 0.8290
#   truly: 0.8268
# Neighbors of culture: Similarity
#   narveson: 0.8498
#   louis: 0.8472
#   was: 0.8451
#   joy: 0.8410
#   flag: 0.8367
#   october: 0.8351
#   interact: 0.8349
#   reformist: 0.8336
#   germany: 0.8335
#   individualist: 0.8327
# Neighbors of insurrection: Similarity
#   rossell: 0.8369
#   dominance: 0.8265
#   striking: 0.8227
#   joined: 0.8216
#   middle: 0.8204
#   operative: 0.8203
#   attempt: 0.8200
#   what: 0.8199
#   sovereignty: 0.8198
#   became: 0.8192
# Neighbors of felt: Similarity
#   mexican: 0.8567
#   relevant: 0.8514
#   meanings: 0.8510
#   shuns: 0.8477
#   predictions: 0.8464
#   berkman: 0.8454
#   g: 0.8453
#   writing: 0.8453
#   ireland: 0.8431
#   saw: 0.8423
# Neighbors of true: Similarity
#   bank: 0.8289
#   bad: 0.8186
#   individualists: 0.8166
#   berkman: 0.8160
#   soviet: 0.8158
#   influential: 0.8157
#   joy: 0.8145
#   are: 0.8141
#   symbolism: 0.8140
#   felt: 0.8139
# Neighbors of membership: Similarity
#   component: 0.8578
#   destruction: 0.8502
#   organise: 0.8486
#   division: 0.8471
#   alternative: 0.8468
#   appleton: 0.8454
#   edition: 0.8436
#   domination: 0.8431
#   negotiations: 0.8405
#   wealth: 0.8401
# Neighbors of neopaganism: Similarity
#   egoist: 0.8326
#   peter: 0.8320
#   offshoots: 0.8294
#   wikipedia: 0.8283
#   detailed: 0.8278
#   religious: 0.8272
#   doctrines: 0.8245
#   value: 0.8219
#   theorists: 0.8209
#   god: 0.8208
# Neighbors of sees: Similarity
#   competition: 0.8592
#   formulation: 0.8527
#   encyclopedia: 0.8457
#   meanings: 0.8429
#   operation: 0.8398
#   autism: 0.8321
#   religious: 0.8310
#   exponent: 0.8305
#   however: 0.8292
#   spreading: 0.8280
# Neighbors of cease: Similarity
#   him: 0.8496
#   dogmatic: 0.8390
#   equality: 0.8337
#   receiving: 0.8321
#   originally: 0.8319
#   oppression: 0.8307
#   UNK: 0.8279
#   also: 0.8265
#   commune: 0.8213
#   regarded: 0.8209
# Neighbors of here: Similarity
#   principles: 0.8441
#   capitalists: 0.8349
#   consolidate: 0.8312
#   oppression: 0.8294
#   human: 0.8276
#   compatibility: 0.8244
#   greek: 0.8220
#   gain: 0.8219
#   respective: 0.8218
#   soon: 0.8217
# Neighbors of george: Similarity
#   repudiated: 0.8470
#   arguing: 0.8403
#   was: 0.8398
#   pseudo: 0.8381
#   inclined: 0.8311
#   practice: 0.8295
#   your: 0.8287
#   interfering: 0.8259
#   among: 0.8255
#   areas: 0.8232
# Neighbors of were: Similarity
#   repudiated: 0.8414
#   essays: 0.8367
#   situationism: 0.8360
#   conditions: 0.8357
#   how: 0.8289
#   characterised: 0.8262
#   incorporated: 0.8225
#   among: 0.8207
#   anarchiste: 0.8204
#   day: 0.8201
# Neighbors of whether: Similarity
#   turn: 0.8431
#   owned: 0.8359
#   etc: 0.8331
#   deal: 0.8314
#   army: 0.8307
#   militant: 0.8302
#   interfering: 0.8287
#   plekhanov: 0.8284
#   lasted: 0.8263
#   i: 0.8253
# Neighbors of confederation: Similarity
#   kind: 0.8460
#   wave: 0.8268
#   environment: 0.8249
#   destroying: 0.8242
#   workingmen: 0.8240
#   conflicts: 0.8230
#   collectivism: 0.8228
#   electoral: 0.8215
#   list: 0.8207
#   individualist: 0.8205
# Neighbors of comes: Similarity
#   city: 0.8538
#   tolstoy: 0.8505
#   crimethinc: 0.8443
#   anarchists: 0.8439
#   turn: 0.8418
#   individualist: 0.8386
#   activists: 0.8383
#   characteristic: 0.8372
#   sensory: 0.8348
#   pseudo: 0.8328
# Neighbors of ayn: Similarity
#   thing: 0.8352
#   mainstream: 0.8329
#   losing: 0.8297
#   consequently: 0.8288
#   preservation: 0.8288
#   played: 0.8287
#   old: 0.8282
#   marxist: 0.8275
#   coercion: 0.8268
#   parties: 0.8265
# Neighbors of mcelroy: Similarity
#   activists: 0.8383
#   truly: 0.8316
#   pursuit: 0.8291
#   flag: 0.8260
#   oppression: 0.8257
#   m: 0.8256
#   revolutionaries: 0.8224
#   like: 0.8216
#   dans: 0.8211
#   competition: 0.8199
# Neighbors of egoism: Similarity
#   conquest: 0.8337
#   k: 0.8323
#   give: 0.8293
#   genuine: 0.8287
#   relevant: 0.8254
#   jean: 0.8223
#   external: 0.8154
#   rise: 0.8153
#   spirituality: 0.8152
#   coherent: 0.8149
# Neighbors of diagnostic: Similarity
#   says: 0.8470
#   predictions: 0.8422
#   criminality: 0.8374
#   xu: 0.8347
#   referred: 0.8336
#   deal: 0.8293
#   stalinists: 0.8252
#   societies: 0.8223
#   experiences: 0.8208
#   democratic: 0.8198
# Neighbors of birth: Similarity
#   unconnected: 0.8664
#   caused: 0.8496
#   aggression: 0.8447
#   earned: 0.8446
#   dynamost: 0.8445
#   feminism: 0.8433
#   de: 0.8426
#   reads: 0.8421
#   since: 0.8410
#   repudiated: 0.8403
# Neighbors of among: Similarity
#   etc: 0.8476
#   victorious: 0.8454
#   dogmatic: 0.8427
#   governance: 0.8422
#   proudhon: 0.8375
#   repression: 0.8372
#   formet: 0.8368
#   consider: 0.8354
#   day: 0.8334
#   societies: 0.8322
# Neighbors of revolutionaries: Similarity
#   their: 0.8485
#   interact: 0.8414
#   respect: 0.8413
#   rejected: 0.8412
#   conceptions: 0.8377
#   k: 0.8374
#   individualist: 0.8335
#   continues: 0.8301
#   life: 0.8301
#   since: 0.8267
# Neighbors of educational: Similarity
#   premise: 0.8337
#   activists: 0.8335
#   talk: 0.8207
#   outposts: 0.8199
#   alston: 0.8114
#   right: 0.8074
#   component: 0.8065
#   to: 0.8061
#   by: 0.8059
#   january: 0.8047
# Neighbors of join: Similarity
#   expression: 0.8556
#   nihilism: 0.8426
#   attempted: 0.8293
#   other: 0.8292
#   spooner: 0.8276
#   arguing: 0.8263
#   seismic: 0.8258
#   ursula: 0.8254
#   discussion: 0.8249
#   mit: 0.8243
# Neighbors of affected: Similarity
#   exchange: 0.8413
#   find: 0.8393
#   oppose: 0.8386
#   rudolf: 0.8372
#   influence: 0.8362
#   glorification: 0.8338
#   bombs: 0.8336
#   look: 0.8321
#   classes: 0.8315
#   voltairine: 0.8314
# Neighbors of recognition: Similarity
#   being: 0.8202
#   gilles: 0.8200
#   their: 0.8194
#   since: 0.8182
#   noam: 0.8181
#   rights: 0.8146
#   researchers: 0.8144
#   characterised: 0.8144
#   coalition: 0.8137
#   develop: 0.8110
# Neighbors of rudolf: Similarity
#   affected: 0.8372
#   mean: 0.8348
#   principles: 0.8339
#   confused: 0.8333
#   can: 0.8325
#   individualists: 0.8316
#   theory: 0.8291
#   ralph: 0.8283
#   might: 0.8279
#   louis: 0.8255
# Neighbors of fairly: Similarity
#   internationals: 0.8347
#   supplant: 0.8346
#   vary: 0.8275
#   someone: 0.8274
#   minor: 0.8262
#   perhaps: 0.8228
#   rossell: 0.8206
#   hold: 0.8188
#   experimental: 0.8186
#   germany: 0.8179
# Neighbors of private: Similarity
#   individualist: 0.8418
#   saul: 0.8354
#   set: 0.8343
#   resist: 0.8333
#   aggression: 0.8330
#   oppression: 0.8319
#   anarchist: 0.8316
#   significant: 0.8304
#   capitalist: 0.8289
#   price: 0.8270
# Neighbors of theorist: Similarity
#   hans: 0.8428
#   truly: 0.8402
#   freedom: 0.8352
#   diggers: 0.8336
#   soviet: 0.8263
#   followed: 0.8249
#   revolution: 0.8246
#   peter: 0.8237
#   narveson: 0.8210
#   must: 0.8208
# Neighbors of took: Similarity
#   etiology: 0.8341
#   autonomous: 0.8330
#   perhaps: 0.8277
#   hop: 0.8247
#   fighting: 0.8236
#   dynamost: 0.8217
#   practice: 0.8216
#   eco: 0.8211
#   revolutions: 0.8203
#   limited: 0.8200
# Neighbors of communistic: Similarity
#   covered: 0.8422
#   term: 0.8392
#   justice: 0.8377
#   kingdom: 0.8324
#   authoritarian: 0.8270
#   indeed: 0.8258
#   communicate: 0.8255
#   famous: 0.8252
#   characteristic: 0.8244
#   alternative: 0.8241
# Neighbors of thriving: Similarity
#   individualists: 0.8347
#   legitimacy: 0.8325
#   prisons: 0.8309
#   dangerous: 0.8284
#   referring: 0.8257
#   marxist: 0.8250
#   statistical: 0.8234
#   results: 0.8232
#   sought: 0.8218
#   rique: 0.8204
# Neighbors of republican: Similarity
#   delays: 0.8638
#   formed: 0.8338
#   mit: 0.8323
#   science: 0.8285
#   spanish: 0.8245
#   characterised: 0.8231
# ...
#   bombs: 0.8381
#   issues: 0.8359
#   icd: 0.8350
# Neighbors of enemies: Similarity
#   someone: 0.8439
#   rise: 0.8290
#   popularity: 0.8280
#   population: 0.8265
#   place: 0.8230
#   indymedia: 0.8208
#   inherent: 0.8197
#   canada: 0.8194
#   worldwide: 0.8185
#   division: 0.8183
# Neighbors of newman: Similarity
#   says: 0.8387
#   importance: 0.8382
#   areas: 0.8331
#   competition: 0.8306
#   eugene: 0.8271
#   culottes: 0.8257
#   marx: 0.8250
#   etc: 0.8249
#   societies: 0.8242
#   occasionally: 0.8206
# Neighbors of liberation: Similarity
#   oppression: 0.8575
#   hart: 0.8378
#   relevant: 0.8302
#   quickest: 0.8266
#   dominance: 0.8259
#   protesters: 0.8247
#   value: 0.8240
#   methodological: 0.8216
#   imaginative: 0.8184
#   soviet: 0.8183
# Neighbors of am: Similarity
#   details: 0.8306
#   rise: 0.8302
#   statistical: 0.8195
#   easily: 0.8193
#   preventing: 0.8160
#   ultimately: 0.8155
#   citium: 0.8150
#   etiology: 0.8143
#   elimination: 0.8142
#   reality: 0.8133
# Neighbors of intellectual: Similarity
#   freely: 0.8472
#   factions: 0.8365
#   union: 0.8363
#   globalization: 0.8344
#   symbolism: 0.8339
#   racial: 0.8331
#   noted: 0.8330
#   fiction: 0.8296
#   howard: 0.8290
#   caused: 0.8284
# Neighbors of goldman: Similarity
#   crimethinc: 0.8201
#   sensory: 0.8121
#   communes: 0.8097
#   related: 0.8014
#   receiving: 0.8004
#   alexander: 0.7998
#   bordering: 0.7995
#   oppression: 0.7977
#   publishing: 0.7941
#   obey: 0.7926
# Neighbors of explaining: Similarity
#   fundamental: 0.8436
#   quite: 0.8423
#   incorporated: 0.8398
#   confederaci: 0.8386
#   systems: 0.8325
#   nihilist: 0.8301
#   subject: 0.8277
#   f: 0.8244
#   your: 0.8228
#   flag: 0.8226
# Neighbors of debate: Similarity
#   organise: 0.8330
#   ultimately: 0.8240
#   caused: 0.8232
#   suggested: 0.8216
#   neighborhood: 0.8197
#   explained: 0.8193
#   absolute: 0.8178
#   science: 0.8175
#   characterised: 0.8163
#   division: 0.8161
# Neighbors of came: Similarity
#   accept: 0.8187
#   predictions: 0.8168
#   population: 0.8054
#   thoughts: 0.8032
#   handle: 0.8030
#   million: 0.8004
#   founded: 0.8000
#   age: 0.8000
#   repression: 0.8000
#   parallel: 0.7962
# Neighbors of lack: Similarity
#   addresses: 0.8331
#   ralph: 0.8274
#   whites: 0.8228
#   hip: 0.8222
#   undermined: 0.8206
#   evolution: 0.8179
#   arbitration: 0.8174
#   communication: 0.8160
#   pervasive: 0.8144
#   majority: 0.8137
# Neighbors of event: Similarity
#   mechanisms: 0.8359
#   leadership: 0.8347
#   education: 0.8333
#   believing: 0.8326
#   attitudes: 0.8324
#   adults: 0.8290
#   resulted: 0.8278
#   coherent: 0.8221
#   region: 0.8216
#   motion: 0.8212
# Neighbors of bakunin: Similarity
#   consider: 0.7892
#   crimethinc: 0.7829
#   taoism: 0.7826
#   willful: 0.7817
#   defunct: 0.7810
#   spirituality: 0.7799
#   pervasive: 0.7766
#   important: 0.7765
#   egalitarian: 0.7757
#   characteristic: 0.7755
# Neighbors of crass: Similarity
#   rumors: 0.8418
#   publishing: 0.8374
#   move: 0.8337
#   addresses: 0.8326
#   use: 0.8291
#   situationism: 0.8286
#   develops: 0.8278
#   shares: 0.8267
#   destruction: 0.8259
#   since: 0.8251
# Neighbors of contexts: Similarity
#   outposts: 0.8558
#   rose: 0.8461
#   degree: 0.8395
#   seeking: 0.8369
#   characterised: 0.8367
#   attitudes: 0.8343
#   occur: 0.8340
#   generalizations: 0.8327
#   globalization: 0.8304
#   refuted: 0.8297
# Neighbors of play: Similarity
#   outspoken: 0.8274
#   commune: 0.8272
#   critique: 0.8257
#   obvious: 0.8203
#   etc: 0.8201
#   publications: 0.8186
#   caused: 0.8185
#   single: 0.8148
#   crimethinc: 0.8148
#   frederick: 0.8147
# Neighbors of magazines: Similarity
#   use: 0.8489
#   sustainability: 0.8360
#   critical: 0.8354
#   cannon: 0.8325
#   imaginative: 0.8300
#   characterised: 0.8295
#   seeking: 0.8293
#   musical: 0.8270
#   primitivism: 0.8262
#   impossible: 0.8261
# Neighbors of inevitable: Similarity
#   quickest: 0.8203
#   amount: 0.8196
#   lacan: 0.8174
#   maintain: 0.8156
#   detailed: 0.8138
#   vary: 0.8137
#   archives: 0.8135
#   means: 0.8131
#   crimethinc: 0.8100
#   alston: 0.8099
# Neighbors of also: Similarity
#   pseudo: 0.8240
#   proto: 0.8205
#   researchers: 0.8144
#   imaginative: 0.8141
#   punk: 0.8082
#   hart: 0.8061
#   interact: 0.8044
#   regarding: 0.8039
#   your: 0.8010
#   since: 0.8010
# Neighbors of sought: Similarity
#   broader: 0.8677
#   vulnerabilities: 0.8664
#   legitimacy: 0.8554
#   meanings: 0.8465
#   disorder: 0.8417
#   precursor: 0.8408
#   ration: 0.8388
#   crimethinc: 0.8383
#   following: 0.8380
#   give: 0.8371
# Neighbors of unfeasible: Similarity
#   maintained: 0.8429
#   birth: 0.8383
#   uprising: 0.8368
#   council: 0.8345
#   illustrated: 0.8277
#   glorification: 0.8277
#   coercion: 0.8230
#   entertainer: 0.8215
#   repudiated: 0.8211
#   whilst: 0.8200
# Neighbors of early: Similarity
#   principle: 0.8108
#   bourgeoisie: 0.8069
#   expression: 0.8018
#   beliefs: 0.7975
#   ultimately: 0.7860
#   six: 0.7848
#   unconnected: 0.7838
#   k: 0.7831
#   turn: 0.7816
#   strategy: 0.7810
# Neighbors of protesters: Similarity
#   domination: 0.8516
#   success: 0.8493
#   formulation: 0.8389
#   city: 0.8371
#   reality: 0.8366
#   undermined: 0.8335
#   guided: 0.8327
#   start: 0.8321
#   peasants: 0.8318
#   tacit: 0.8293
# Neighbors of central: Similarity
#   followed: 0.8122
#   mcelroy: 0.8004
#   bolsheviks: 0.7907
#   founded: 0.7872
#   tests: 0.7839
#   topic: 0.7836
#   haymarket: 0.7835
#   maintained: 0.7825
#   out: 0.7820
#   engels: 0.7818
# Neighbors of general: Similarity
#   leaders: 0.8011
#   coercive: 0.7868
#   todd: 0.7861
#   primitive: 0.7763
#   situationism: 0.7743
#   preservation: 0.7729
#   inspired: 0.7729
#   critique: 0.7720
#   seminal: 0.7715
#   exchange: 0.7663
# Neighbors of moment: Similarity
#   region: 0.8454
#   develop: 0.8353
#   autonomous: 0.8322
#   eclectic: 0.8305
#   anthropologists: 0.8285
#   characteristic: 0.8277
#   catalonia: 0.8249
#   community: 0.8247
#   associating: 0.8246
#   value: 0.8224
# Neighbors of utterly: Similarity
#   leftism: 0.8128
#   shares: 0.8104
#   characteristic: 0.8094
#   publishing: 0.8071
#   quickest: 0.8032
#   individualists: 0.8005
#   abstention: 0.7977
#   criticizes: 0.7976
#   crimethinc: 0.7963
#   repudiated: 0.7959
# Neighbors of lumpenproletariat: Similarity
#   damage: 0.8223
#   specifically: 0.8163
#   quite: 0.8119
#   stanley: 0.8112
#   abolition: 0.8080
#   workingmen: 0.8079
#   ego: 0.8052
#   overwhelming: 0.8050
#   degree: 0.8040
#   tend: 0.8026
# Neighbors of how: Similarity
#   decades: 0.8416
#   suggested: 0.8367
#   whoever: 0.8309
#   oppression: 0.8298
#   disagreement: 0.8280
#   further: 0.8278
#   taking: 0.8245
#   stalinists: 0.8227
#   region: 0.8218
#   formed: 0.8207
# Neighbors of formal: Similarity
#   alternate: 0.8284
#   color: 0.8272
#   internet: 0.8254
#   undermined: 0.8243
#   troops: 0.8222
#   taking: 0.8199
#   nihilist: 0.8191
#   supplant: 0.8172
#   spreading: 0.8150
#   present: 0.8146
# Neighbors of neocolonialism: Similarity
#   bank: 0.8385
#   favor: 0.8342
#   confines: 0.8317
#   prevalent: 0.8286
#   prior: 0.8263
#   antifa: 0.8259
#   organise: 0.8251
#   noted: 0.8246
#   extensively: 0.8241
#   interactions: 0.8234
# Neighbors of th: Similarity
#   neurodevelopmental: 0.8088
#   goals: 0.7984
#   five: 0.7844
#   entertainer: 0.7827
#   experimental: 0.7764
#   auberon: 0.7756
#   individualists: 0.7717
#   factors: 0.7716
#   famous: 0.7702
#   sitting: 0.7701
# Neighbors of practice: Similarity
#   bios: 0.8531
#   hierarchical: 0.8448
#   peasants: 0.8409
#   sitting: 0.8394
#   changed: 0.8386
#   importance: 0.8385
#   seeks: 0.8369
#   mediation: 0.8364
#   f: 0.8334
#   referred: 0.8326
# Neighbors of peter: Similarity
#   seeks: 0.8306
#   characteristic: 0.8256
#   banking: 0.8243
#   neopaganism: 0.8242
#   changed: 0.8215
#   existing: 0.8215
#   reality: 0.8213
#   germinal: 0.8201
#   hans: 0.8193
#   cleyre: 0.8185
# Neighbors of economics: Similarity
#   damage: 0.8542
#   usher: 0.8435
#   forms: 0.8433
#   mechanisms: 0.8376
#   move: 0.8332
#   proclivities: 0.8326
#   defend: 0.8324
#   since: 0.8312
#   defeat: 0.8301
#   deal: 0.8263
# Neighbors of hierarchy: Similarity
#   classes: 0.8431
#   wiki: 0.8346
#   give: 0.8345
#   oppression: 0.8333
#   researchers: 0.8321
#   rose: 0.8290
#   adjectives: 0.8280
#   decades: 0.8274
#   external: 0.8273
#   overwhelming: 0.8259
# Neighbors of professing: Similarity
#   programming: 0.8209
#   move: 0.8204
#   hans: 0.8195
#   relevant: 0.8183
#   characterised: 0.8175
#   external: 0.8135
#   consider: 0.8119
#   forms: 0.8113
#   decades: 0.8101
#   voting: 0.8098
# Neighbors of city: Similarity
#   pseudo: 0.8508
#   significant: 0.8485
#   does: 0.8466
#   wildly: 0.8456
#   destroying: 0.8444
#   comes: 0.8414
#   seeks: 0.8413
#   precursor: 0.8413
#   developments: 0.8382
#   landauer: 0.8382
# Neighbors of elections: Similarity
#   autos: 0.8248
#   onset: 0.8240
#   destruction: 0.8201
#   birth: 0.8165
#   whites: 0.8151
#   criticsed: 0.8148
#   nevertheless: 0.8142
#   ancestors: 0.8115
#   makes: 0.8102
#   capitalists: 0.8085
# Neighbors of peasants: Similarity
#   crimethinc: 0.8465
#   changed: 0.8465
#   practice: 0.8409
#   text: 0.8398
#   relevant: 0.8360
#   inherent: 0.8355
#   earth: 0.8335
#   transformed: 0.8322
#   protesters: 0.8318
#   dr: 0.8310
# Neighbors of french: Similarity
#   king: 0.8351
#   mbah: 0.8182
#   rise: 0.8123
#   paid: 0.8084
#   arrive: 0.8082
#   publications: 0.8069
#   almost: 0.8061
#   monopoly: 0.8052
#   term: 0.8051
#   puente: 0.8045
# Neighbors of bertrand: Similarity
#   kinds: 0.8552
#   violence: 0.8375
#   originated: 0.8330
#   crimethinc: 0.8261
#   focuses: 0.8229
#   vii: 0.8215
#   perhaps: 0.8175
#   errico: 0.8172
#   riots: 0.8160
#   stoic: 0.8151
# Neighbors of eight: Similarity
#   zero: 0.8335
#   three: 0.8239
#   nine: 0.8213
#   communes: 0.7968
#   nihilist: 0.7895
#   prevalent: 0.7868
#   deed: 0.7842
#   pervasive: 0.7804
#   heavily: 0.7793
#   internationals: 0.7780
# Neighbors of worldwide: Similarity
#   list: 0.8511
#   barcelona: 0.8383
#   stanley: 0.8353
#   mechanisms: 0.8301
#   oppression: 0.8297
#   science: 0.8288
#   disorders: 0.8284
#   smith: 0.8281
#   physiologically: 0.8273
#   statistical: 0.8271
# Neighbors of inherent: Similarity
#   stanley: 0.8474
#   etc: 0.8429
#   mysogyny: 0.8396
#   referred: 0.8371
#   someone: 0.8370
#   peasants: 0.8355
#   societies: 0.8344
#   perhaps: 0.8315
#   totalitarians: 0.8259
#   oppression: 0.8257
# Neighbors of without: Similarity
#   website: 0.8435
#   organise: 0.8315
#   dynamost: 0.8284
#   zapatista: 0.8268
#   followed: 0.8252
#   stanley: 0.8201
#   northeastern: 0.8199
#   rique: 0.8162
#   associations: 0.8156
#   list: 0.8152
# Neighbors of those: Similarity
#   occupation: 0.8017
#   followed: 0.7957
#   ancestors: 0.7929
#   helps: 0.7921
#   soviet: 0.7902
#   neighborhood: 0.7895
#   traditions: 0.7886
#   voltairine: 0.7885
#   affected: 0.7880
#   alternative: 0.7855
# Neighbors of reported: Similarity
#   herbert: 0.8227
#   council: 0.8221
#   minarchists: 0.8169
#   favor: 0.8159
#   autonomous: 0.8116
#   precursor: 0.8100
#   communitarian: 0.8093
#   science: 0.8079
#   production: 0.8076
#   zeno: 0.8075
# Neighbors of translated: Similarity
#   e: 0.8497
#   position: 0.8412
#   subject: 0.8379
#   may: 0.8377
#   rothbard: 0.8353
#   indymedia: 0.8339
#   grew: 0.8310
#   mag: 0.8285
#   rise: 0.8280
#   oppression: 0.8265
# Neighbors of troops: Similarity
#   color: 0.8271
#   formal: 0.8222
#   oppression: 0.8185
#   region: 0.8113
#   exchange: 0.8087
#   manifestation: 0.8069
#   inclined: 0.8063
#   hart: 0.8051
#   coexist: 0.8046
#   predominantly: 0.8037
# Neighbors of harmonious: Similarity
#   portrayed: 0.8289
#   organise: 0.8188
#   tending: 0.8164
#   largest: 0.8146
#   issues: 0.8116
#   characteristic: 0.8093
#   advance: 0.8093
#   contexts: 0.8085
#   stalinist: 0.8077
#   oppressive: 0.8070
# Neighbors of whites: Similarity
#   criticsed: 0.8464
#   austrian: 0.8395
#   quickest: 0.8393
#   persecuted: 0.8384
#   arbitration: 0.8365
#   meanings: 0.8350
#   unnecessary: 0.8334
#   broader: 0.8333
#   popularized: 0.8317
#   following: 0.8305
# Neighbors of influence: Similarity
#   widespread: 0.8417
#   affected: 0.8362
#   relevant: 0.8335
#   prisons: 0.8295
#   revolutionist: 0.8267
#   seeks: 0.8262
#   fundamental: 0.8254
#   berlin: 0.8250
#   manner: 0.8249
#   dilettantes: 0.8244
# Neighbors of already: Similarity
#   stimulations: 0.8378
#   tree: 0.8376
#   detailed: 0.8353
#   encyclopedia: 0.8352
#   f: 0.8267
#   earned: 0.8246
#   dismiss: 0.8228
#   oppression: 0.8224
#   dedicated: 0.8221
#   riot: 0.8218
# Neighbors of went: Similarity
#   maintain: 0.8470
#   population: 0.8391
#   situationism: 0.8389
#   moral: 0.8380
#   council: 0.8351
#   oppression: 0.8333
#   upon: 0.8318
#   regarding: 0.8244
#   interfering: 0.8226
#   hop: 0.8217
# Neighbors of factors: Similarity
#   component: 0.8394
#   heterodox: 0.8369
#   developments: 0.8365
#   believes: 0.8311
#   react: 0.8292
#   group: 0.8287
#   because: 0.8281
#   stoic: 0.8278
#   tending: 0.8277
#   spirituality: 0.8263
# 100%|██████████| 20/20 [31:15<00:00, 93.78s/it]
# Neighbors of exhibits: Similarity
#   riot: 0.8366
#   todd: 0.8318
#   crimethinc: 0.8317
#   uprising: 0.8248
#   rebellion: 0.8243
#   since: 0.8241
#   confronting: 0.8216
#   competition: 0.8201
#   systems: 0.8197
#   hip: 0.8193
# Neighbors of swiss: Similarity
#   owen: 0.8467
#   neither: 0.8425
#   symbolism: 0.8366
#   narveson: 0.8347
#   scale: 0.8347
#   disobedience: 0.8333
#   hip: 0.8333
#   societies: 0.8332
#   culture: 0.8330
#   earned: 0.8321
# Neighbors of conscience: Similarity
#   milieu: 0.8191
#   never: 0.8177
#   originally: 0.8107
#   followed: 0.8101
#   rothbard: 0.8095
#   moniker: 0.8091
#   jan: 0.8081
#   escape: 0.8065
#   guattari: 0.8063
#   generalizations: 0.8062
# Neighbors of description: Similarity
#   primary: 0.8475
#   syncretic: 0.8461
#   starhawk: 0.8415
#   make: 0.8372
#   extensive: 0.8324
#   list: 0.8302
#   consequently: 0.8295
#   worldview: 0.8292
#   mysogyny: 0.8277
#   prisons: 0.8266
# Neighbors of johann: Similarity
#   thinkers: 0.8229
#   detailed: 0.8203
#   hospital: 0.8202
#   guattari: 0.8169
#   methodological: 0.8159
#   hip: 0.8149
#   separate: 0.8132
#   anarchiste: 0.8128
#   details: 0.8099
#   condition: 0.8099
# Neighbors of belongs: Similarity
#   institution: 0.8401
#   earned: 0.8302
#   oppression: 0.8262
#   religious: 0.8247
#   formed: 0.8227
#   bourgeoisie: 0.8206
#   outposts: 0.8170
#   copenhagen: 0.8169
#   kanner: 0.8140
#   freetown: 0.8120
# Neighbors of rose: Similarity
#   dynamics: 0.8487
#   contexts: 0.8461
#   broad: 0.8451
#   develops: 0.8414
#   deal: 0.8362
#   pacifism: 0.8335
#   failed: 0.8326
#   germinal: 0.8320
#   maintain: 0.8320
#   compete: 0.8307
# Neighbors of forms: Similarity
#   events: 0.8548
#   third: 0.8446
#   band: 0.8434
#   economics: 0.8433
#   defend: 0.8430
#   proceeded: 0.8429
#   mechanisms: 0.8396
#   context: 0.8357
#   arrive: 0.8333
#   advance: 0.8277
# Neighbors of hierarchies: Similarity
#   autonomist: 0.8332
#   deal: 0.8311
#   environment: 0.8309
#   bombings: 0.8284
#   owners: 0.8281
#   arms: 0.8274
#   argue: 0.8268
#   favoured: 0.8266
#   capitalists: 0.8253
#   activism: 0.8247
# Neighbors of catalonia: Similarity
#   elimination: 0.8481
#   hospital: 0.8335
#   oppression: 0.8316
#   similar: 0.8309
#   makes: 0.8285
#   moment: 0.8249
#   andrej: 0.8240
#   opposes: 0.8230
#   compatibility: 0.8217
#   says: 0.8207
# Neighbors of incidence: Similarity
#   formed: 0.8430
#   successful: 0.8429
#   oppression: 0.8407
#   lead: 0.8404
#   delays: 0.8326
#   famous: 0.8284
#   celebrated: 0.8282
#   joy: 0.8246
#   founded: 0.8211
#   patterns: 0.8201
# Neighbors of production: Similarity
#   oppression: 0.8352
#   characterised: 0.8325
#   justice: 0.8303
#   place: 0.8299
#   flag: 0.8293
#   crisis: 0.8268
#   societies: 0.8265
#   estimate: 0.8239
#   founder: 0.8233
#   ways: 0.8219
# Neighbors of bureaucratic: Similarity
#   precursor: 0.8402
#   manner: 0.8350
#   woodworth: 0.8235
#   gain: 0.8218
#   can: 0.8200
#   vulnerabilities: 0.8193
#   list: 0.8179
#   rise: 0.8174
#   bombings: 0.8149
#   insurrectionary: 0.8144
# Neighbors of trade: Similarity
#   genes: 0.8205
#   large: 0.8055
#   nonviolent: 0.8035
#   victor: 0.8029
#   overthrown: 0.8024
#   created: 0.8019
#   mean: 0.8006
#   tacit: 0.7959
#   state: 0.7940
#   celebrated: 0.7914
# Neighbors of tends: Similarity
#   organise: 0.8554
#   october: 0.8350
#   symbolic: 0.8350
#   component: 0.8308
#   further: 0.8308
#   prior: 0.8286
#   hans: 0.8277
#   began: 0.8273
#   science: 0.8254
#   metaphor: 0.8248
# Neighbors of leader: Similarity
#   continuing: 0.8307
#   organising: 0.8233
#   nuclear: 0.8229
#   germany: 0.8225
#   characteristic: 0.8216
#   try: 0.8214
#   failed: 0.8212
#   soviet: 0.8203
#   divided: 0.8180
#   f: 0.8159
# Neighbors of autonomism: Similarity
#   utility: 0.8496
#   stateless: 0.8309
#   tendency: 0.8308
#   argentina: 0.8305
#   mexican: 0.8296
#   neighborhood: 0.8288
#   someone: 0.8282
#   handle: 0.8282
#   look: 0.8275
#   consequently: 0.8232

# %%
import numpy as np
import pickle

# 保存和加载预训练词嵌入向量，计算相似度
class WordEmbedding:
    def __init__(self, embedding_matrix):
        self.embedding_matrix = embedding_matrix

    def save_embeddings(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.embedding_matrix, f)

    def load_embeddings(self, filename):
        with open(filename, 'rb') as f:
            self.embedding_matrix = pickle.load(f)

    def get_similarity(self, word_id1, word_id2):
        vec1 = self.embedding_matrix[word_id1]
        vec2 = self.embedding_matrix[word_id2]
        return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
# 测试Word2Vec
embedding_matrix = w2v.W1
we = WordEmbedding(embedding_matrix)
we.save_embeddings("wordembedding.pkl")
we.load_embeddings("wordembedding.pkl")
similarity = we.get_similarity(dictionary["anarchism"], dictionary["originated"])
print(f"The Similarity of pejorative and describe: {similarity}")
# Out:
# The Similarity of pejorative and describe: 0.6548557201440164
